# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import urllib.parse
import re
import numpy as np
import seaborn as sns
import ast
from wordcloud import WordCloud, STOPWORDS
import sklearn
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.decomposition import PCA
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils import resample
import xgboost as xgb
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.feature_selection import SelectFromModel
from collections import defaultdict
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, confusion_matrix

# %%
df = pd.read_parquet('/Users/lijiazheng/Desktop/completion_model_embeddings.parquet')
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = pd.read_parquet('/Users/lijiazheng/Desktop/completion_model_embeddings.parquet')
#       2 df
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parquet.py:281, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     273 try:
#     274     pa_table = self.api.parquet.read_table(
#     275         path_or_handle,
#     276         columns=columns,
#    (...)
#     279         **kwargs,
#     280     )
# --> 281     result = pa_table.to_pandas(**to_pandas_kwargs)
#     283     if manager == "array":
#     284         result = result._as_manager("array", copy=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyarrow/array.pxi:872, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyarrow/table.pxi:4904, in pyarrow.lib.Table._to_pandas()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pyarrow/pandas_compat.py:779, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     776 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     778 column_names = table.column_names
# --> 779 result = pa.lib.table_to_blocks(options, table, categories,
#     780                                 list(ext_columns_dtypes.keys()))
#     781 if _pandas_api.is_ge_v3():
#     782     from pandas.api.internals import create_dataframe_from_blocks
#
# KeyboardInterrupt:

# %%
df['status_binary'] = (df['statusModule_overallStatus'] == 'COMPLETED').astype(int)
print(df['status_binary'].value_counts())

df = df.drop(columns = ['identificationModule_nctId','statusModule_overallStatus', 'combined_description'])
# Out:
# status_binary
# 1    223519
# 0     39929
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report
# === CONFIG ===
n_runs = 5
desired_ratio = 1
param_grid = {
    'n_estimators': [300, 400, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.2],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8]
}

# === RESULTS STORAGE ===
results = defaultdict(list)

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.05, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

    def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
        clf = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)
        grid = GridSearchCV(clf, param_grid, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)
        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        y_pred = best_model.predict(X_test)
        y_prob = best_model.predict_proba(X_test)[:, 1]

        auc = roc_auc_score(y_test, y_prob)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # <-- Add classification report here
        report = classification_report(y_test, y_pred, output_dict=True)

        result = {
            'auc': auc,
            'precision': precision,
            'recall': recall,
            'accuracy': accuracy,
            'f1': f1,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'report': report  
        }

        if return_importance and feature_names is not None:
            importances = best_model.feature_importances_
            feature_importance_dict = dict(zip(feature_names, importances))
            result['feature_importance'] = feature_importance_dict

        return result

    # === Train and Evaluate ===
    # Pass selected feature names after feature selection
    metrics_no_emb = train_and_eval_all(
        X_train_sel, y_train, X_test_sel, y_test,
        feature_names=selected_feature_names,
        return_importance=True
    )

    metrics_with_emb = train_and_eval_all(
        X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
    results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

    # Save metrics to results
    for metric, value in metrics_no_emb.items():
        results[f'no_emb_{metric}'].append(value)
    for metric, value in metrics_with_emb.items():
        results[f'with_emb_{metric}'].append(value)
    
    results['no_emb_reports'].append(metrics_no_emb['report'])
    results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===

print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# ===================== Run 1/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 2/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 3/5 =====================
# Optimal PCA components: 317
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 4/5 =====================
# Optimal PCA components: 317
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 5/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.2307
# healthyVolunteers_yes: 0.1141
# healthyVolunteers_no: 0.0758
# FdaRegulatedDrug_yes: 0.0677
# interventionModel_PARALLEL: 0.0424
# Neoplasms: 0.0392
# duration_of_trial: 0.0344
# FdaRegulatedDevice_yes: 0.0331
# organization_class_INDUSTRY: 0.0329
# interventionModel_CROSSOVER: 0.0319
# facility_count: 0.0314
# PHASE3: 0.0262
# FdaRegulatedDrug_no: 0.0236
# PHASE2: 0.0231
# leadsponsor_INDUSTRY: 0.0231
# masking_SINGLE: 0.0227
# interventionModel_SEQUENTIAL: 0.0224
# FdaRegulatedDevice_no: 0.0208
# oversightHasDmc_yes: 0.0202
# PHASE4: 0.0199
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score         support
# 0     0  0.85 ± 0.00  0.73 ± 0.00  0.78 ± 0.00  7986.00 ± 0.00
# 1     1  0.76 ± 0.00  0.87 ± 0.00  0.81 ± 0.00  7986.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score         support
# 0     0  0.85 ± 0.00  0.74 ± 0.01  0.79 ± 0.00  7986.00 ± 0.00
# 1     1  0.77 ± 0.00  0.87 ± 0.00  0.82 ± 0.00  7986.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.01825971,
#                'designModule_enrollmentInfo_count': 0.21953008,
#                'leadsponsor_INDUSTRY': 0.019116016,
#                'PHASE2': 0.027924849,
#                'PHASE3': 0.026242325,
#                'organization_class_INDUSTRY': 0.04184658,
#                'oversightHasDmc_no': 0.017507426,
#                'oversightHasDmc_yes': 0.023333177,
#                'FdaRegulatedDrug_yes': 0.069107555,
#                'FdaRegulatedDevice_no': 0.024310622,
#                'FdaRegulatedDevice_yes': 0.032334503,
#                'designInfo_allocation_NON_RANDOMIZED': 0.019889154,
#                'interventionModel_CROSSOVER': 0.037497047,
#                'interventionModel_PARALLEL': 0.04372207,
#                'primaryPurpose_DIAGNOSTIC': 0.020611009,
#                'masking_SINGLE': 0.02604322,
#                'healthyVolunteers_no': 0.12593266,
#                'healthyVolunteers_yes': 0.06594544,
#                'duration_of_trial': 0.037496388,
#                'facility_count': 0.034422252,
#                'Neoplasms': 0.045361664,
#                'collaborator_NIH': 0.023566308},
#               {'eligibilityModule_maximumAge': 0.014350542,
#                'designModule_enrollmentInfo_count': 0.238286,
#                'PHASE2': 0.020649921,
#                'PHASE3': 0.02688842,
#                'organization_class_INDUSTRY': 0.02705927,
#                'oversightHasDmc_no': 0.010278402,
#                'oversightHasDmc_yes': 0.01867904,
#                'FdaRegulatedDrug_no': 0.02379917,
#                'FdaRegulatedDrug_yes': 0.075513475,
#                'FdaRegulatedDevice_no': 0.017695876,
#                'FdaRegulatedDevice_yes': 0.03051651,
#                'interventionModel_CROSSOVER': 0.032525998,
#                'interventionModel_PARALLEL': 0.03772184,
#                'interventionModel_SEQUENTIAL': 0.021811677,
#                'primaryPurpose_DIAGNOSTIC': 0.01472509,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.017060457,
#                'masking_SINGLE': 0.02196965,
#                'healthyVolunteers_no': 0.043479025,
#                'healthyVolunteers_yes': 0.16917606,
#                'sex_male': 0.017340234,
#                'duration_of_trial': 0.031774633,
#                'facility_count': 0.029924864,
#                'Neoplasms': 0.041147318,
#                'collaborator_NIH': 0.017626524},
#               {'eligibilityModule_maximumAge': 0.01579713,
#                'designModule_enrollmentInfo_count': 0.21891102,
#                'leadsponsor_FED': 0.014538262,
#                'leadsponsor_INDUSTRY': 0.01943488,
#                'PHASE2': 0.022029042,
#                'PHASE3': 0.028071987,
#                'organization_class_INDUSTRY': 0.030867713,
#                'oversightHasDmc_no': 0.013689685,
#                'oversightHasDmc_yes': 0.018425709,
#                'FdaRegulatedDrug_no': 0.023696031,
#                'FdaRegulatedDrug_yes': 0.050970707,
#                'FdaRegulatedDevice_no': 0.020368397,
#                'interventionModel_CROSSOVER': 0.025802428,
#                'interventionModel_PARALLEL': 0.04366231,
#                'interventionModel_SEQUENTIAL': 0.023023635,
#                'primaryPurpose_DIAGNOSTIC': 0.021488424,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.020497577,
#                'masking_SINGLE': 0.021239782,
#                'healthyVolunteers_no': 0.08825532,
#                'healthyVolunteers_yes': 0.083493076,
#                'piSponsorEmployee_no': 0.015286654,
#                'piSponsorEmployee_yes': 0.019763974,
#                'duration_of_trial': 0.030203206,
#                'facility_count': 0.03227855,
#                'Infections': 0.014968423,
#                'Neoplasms': 0.03379096,
#                'Stomatognathic Diseases': 0.018271975,
#                'Respiratory Tract Diseases': 0.013660684,
#                'collaborator_NIH': 0.017512348},
#               {'eligibilityModule_maximumAge': 0.016485455,
#                'designModule_enrollmentInfo_count': 0.24503355,
#                'leadsponsor_INDUSTRY': 0.029280864,
#                'leadsponsor_OTHER': 0.013257996,
#                'PHASE2': 0.022102278,
#                'PHASE3': 0.026485957,
#                'PHASE4': 0.01992568,
#                'organization_class_INDUSTRY': 0.031299323,
#                'organization_class_OTHER': 0.01760144,
#                'oversightHasDmc_no': 0.013763162,
#                'oversightHasDmc_yes': 0.020476004,
#                'FdaRegulatedDrug_yes': 0.077521235,
#                'FdaRegulatedDevice_no': 0.020341787,
#                'FdaRegulatedDevice_yes': 0.036382716,
#                'interventionModel_CROSSOVER': 0.0338736,
#                'interventionModel_PARALLEL': 0.043927778,
#                'primaryPurpose_DIAGNOSTIC': 0.0177489,
#                'masking_SINGLE': 0.022597564,
#                'healthyVolunteers_no': 0.07664536,
#                'healthyVolunteers_yes': 0.078631796,
#                'duration_of_trial': 0.036039725,
#                'facility_count': 0.029039444,
#                'Neoplasms': 0.037270557,
#                'collaborator_NIH': 0.018495405,
#                'Organic Chemicals': 0.015772441},
#               {'eligibilityModule_maximumAge': 0.017275127,
#                'designModule_enrollmentInfo_count': 0.23189174,
#                'leadsponsor_INDUSTRY': 0.024432605,
#                'PHASE2': 0.02292997,
#                'PHASE3': 0.023323067,
#                'organization_class_INDUSTRY': 0.033511043,
#                'oversightHasDmc_yes': 0.020062305,
#                'FdaRegulatedDrug_no': 0.02322955,
#                'FdaRegulatedDrug_yes': 0.06526981,
#                'FdaRegulatedDevice_no': 0.02150342,
#                'interventionModel_CROSSOVER': 0.029568354,
#                'interventionModel_PARALLEL': 0.0429417,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.018222116,
#                'masking_SINGLE': 0.021456517,
#                'healthyVolunteers_no': 0.044781845,
#                'healthyVolunteers_yes': 0.17323942,
#                'sex_male': 0.020267325,
#                'restrictiveAgreement_yes': 0.018391136,
#                'duration_of_trial': 0.036371123,
#                'facility_count': 0.03131815,
#                'Infections': 0.019345397,
#                'Neoplasms': 0.03851631,
#                'collaborator_NIH': 0.022151906}],
#              'no_emb_auc': [0.8805596291757506,
#               0.8824493702948353,
#               0.8802193454749168,
#               0.8862684911467595,
#               0.883636137533195],
#              'no_emb_precision': [0.7617105698225505,
#               0.7630051473004053,
#               0.7575988669789737,
#               0.7672167216721673,
#               0.7634194831013916],
#              'no_emb_recall': [0.865389431505134,
#               0.8724017029802154,
#               0.8707738542449286,
#               0.8732782369146006,
#               0.8655146506386175],
#              'no_emb_accuracy': [0.7973328324567994,
#               0.8007137490608565,
#               0.7960806411219634,
#               0.8041572752316554,
#               0.7986476333583772],
#              'no_emb_f1': [0.8102467905504426,
#               0.8140445171466962,
#               0.8102534226623944,
#               0.8168189271492152,
#               0.8112676056338028],
#              'no_emb_tp': [6911, 6967, 6954, 6974, 6912],
#              'no_emb_tn': [5824, 5822, 5761, 5870, 5844],
#              'no_emb_fp': [2162, 2164, 2225, 2116, 2142],
#              'no_emb_fn': [1075, 1019, 1032, 1012, 1074],
#              'no_emb_report': [{'0': {'precision': 0.8441803159878243,
#                 'recall': 0.7292762334084648,
#                 'f1-score': 0.7825327510917031,
#                 'support': 7986.0},
#                '1': {'precision': 0.7617105698225505,
#                 'recall': 0.865389431505134,
#                 'f1-score': 0.8102467905504426,
#                 'support': 7986.0},
#                'accuracy': 0.7973328324567994,
#                'macro avg': {'precision': 0.8029454429051874,
#                 'recall': 0.7973328324567994,
#                 'f1-score': 0.7963897708210728,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8029454429051873,
#                 'recall': 0.7973328324567994,
#                 'f1-score': 0.7963897708210728,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8510451688349656,
#                 'recall': 0.7290257951414976,
#                 'f1-score': 0.7853240709516423,
#                 'support': 7986.0},
#                '1': {'precision': 0.7630051473004053,
#                 'recall': 0.8724017029802154,
#                 'f1-score': 0.8140445171466962,
#                 'support': 7986.0},
#                'accuracy': 0.8007137490608565,
#                'macro avg': {'precision': 0.8070251580676855,
#                 'recall': 0.8007137490608565,
#                 'f1-score': 0.7996842940491693,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8070251580676855,
#                 'recall': 0.8007137490608565,
#                 'f1-score': 0.7996842940491693,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8480789047548948,
#                 'recall': 0.7213874279989982,
#                 'f1-score': 0.7796197306989647,
#                 'support': 7986.0},
#                '1': {'precision': 0.7575988669789737,
#                 'recall': 0.8707738542449286,
#                 'f1-score': 0.8102534226623944,
#                 'support': 7986.0},
#                'accuracy': 0.7960806411219634,
#                'macro avg': {'precision': 0.8028388858669342,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.7949365766806795,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8028388858669342,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.7949365766806795,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8529497239174658,
#                 'recall': 0.7350363135487102,
#                 'f1-score': 0.7896152811407049,
#                 'support': 7986.0},
#                '1': {'precision': 0.7672167216721673,
#                 'recall': 0.8732782369146006,
#                 'f1-score': 0.8168189271492152,
#                 'support': 7986.0},
#                'accuracy': 0.8041572752316554,
#                'macro avg': {'precision': 0.8100832227948165,
#                 'recall': 0.8041572752316555,
#                 'f1-score': 0.8032171041449601,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8100832227948165,
#                 'recall': 0.8041572752316554,
#                 'f1-score': 0.8032171041449601,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8447528187337381,
#                 'recall': 0.7317806160781367,
#                 'f1-score': 0.784219001610306,
#                 'support': 7986.0},
#                '1': {'precision': 0.7634194831013916,
#                 'recall': 0.8655146506386175,
#                 'f1-score': 0.8112676056338028,
#                 'support': 7986.0},
#                'accuracy': 0.7986476333583772,
#                'macro avg': {'precision': 0.8040861509175649,
#                 'recall': 0.7986476333583772,
#                 'f1-score': 0.7977433036220545,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8040861509175649,
#                 'recall': 0.7986476333583772,
#                 'f1-score': 0.7977433036220544,
#                 'support': 15972.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.01825971,
#                'designModule_enrollmentInfo_count': 0.21953008,
#                'leadsponsor_INDUSTRY': 0.019116016,
#                'PHASE2': 0.027924849,
#                'PHASE3': 0.026242325,
#                'organization_class_INDUSTRY': 0.04184658,
#                'oversightHasDmc_no': 0.017507426,
#                'oversightHasDmc_yes': 0.023333177,
#                'FdaRegulatedDrug_yes': 0.069107555,
#                'FdaRegulatedDevice_no': 0.024310622,
#                'FdaRegulatedDevice_yes': 0.032334503,
#                'designInfo_allocation_NON_RANDOMIZED': 0.019889154,
#                'interventionModel_CROSSOVER': 0.037497047,
#                'interventionModel_PARALLEL': 0.04372207,
#                'primaryPurpose_DIAGNOSTIC': 0.020611009,
#                'masking_SINGLE': 0.02604322,
#                'healthyVolunteers_no': 0.12593266,
#                'healthyVolunteers_yes': 0.06594544,
#                'duration_of_trial': 0.037496388,
#                'facility_count': 0.034422252,
#                'Neoplasms': 0.045361664,
#                'collaborator_NIH': 0.023566308},
#               {'eligibilityModule_maximumAge': 0.014350542,
#                'designModule_enrollmentInfo_count': 0.238286,
#                'PHASE2': 0.020649921,
#                'PHASE3': 0.02688842,
#                'organization_class_INDUSTRY': 0.02705927,
#                'oversightHasDmc_no': 0.010278402,
#                'oversightHasDmc_yes': 0.01867904,
#                'FdaRegulatedDrug_no': 0.02379917,
#                'FdaRegulatedDrug_yes': 0.075513475,
#                'FdaRegulatedDevice_no': 0.017695876,
#                'FdaRegulatedDevice_yes': 0.03051651,
#                'interventionModel_CROSSOVER': 0.032525998,
#                'interventionModel_PARALLEL': 0.03772184,
#                'interventionModel_SEQUENTIAL': 0.021811677,
#                'primaryPurpose_DIAGNOSTIC': 0.01472509,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.017060457,
#                'masking_SINGLE': 0.02196965,
#                'healthyVolunteers_no': 0.043479025,
#                'healthyVolunteers_yes': 0.16917606,
#                'sex_male': 0.017340234,
#                'duration_of_trial': 0.031774633,
#                'facility_count': 0.029924864,
#                'Neoplasms': 0.041147318,
#                'collaborator_NIH': 0.017626524},
#               {'eligibilityModule_maximumAge': 0.01579713,
#                'designModule_enrollmentInfo_count': 0.21891102,
#                'leadsponsor_FED': 0.014538262,
#                'leadsponsor_INDUSTRY': 0.01943488,
#                'PHASE2': 0.022029042,
#                'PHASE3': 0.028071987,
#                'organization_class_INDUSTRY': 0.030867713,
#                'oversightHasDmc_no': 0.013689685,
#                'oversightHasDmc_yes': 0.018425709,
#                'FdaRegulatedDrug_no': 0.023696031,
#                'FdaRegulatedDrug_yes': 0.050970707,
#                'FdaRegulatedDevice_no': 0.020368397,
#                'interventionModel_CROSSOVER': 0.025802428,
#                'interventionModel_PARALLEL': 0.04366231,
#                'interventionModel_SEQUENTIAL': 0.023023635,
#                'primaryPurpose_DIAGNOSTIC': 0.021488424,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.020497577,
#                'masking_SINGLE': 0.021239782,
#                'healthyVolunteers_no': 0.08825532,
#                'healthyVolunteers_yes': 0.083493076,
#                'piSponsorEmployee_no': 0.015286654,
#                'piSponsorEmployee_yes': 0.019763974,
#                'duration_of_trial': 0.030203206,
#                'facility_count': 0.03227855,
#                'Infections': 0.014968423,
#                'Neoplasms': 0.03379096,
#                'Stomatognathic Diseases': 0.018271975,
#                'Respiratory Tract Diseases': 0.013660684,
#                'collaborator_NIH': 0.017512348},
#               {'eligibilityModule_maximumAge': 0.016485455,
#                'designModule_enrollmentInfo_count': 0.24503355,
#                'leadsponsor_INDUSTRY': 0.029280864,
#                'leadsponsor_OTHER': 0.013257996,
#                'PHASE2': 0.022102278,
#                'PHASE3': 0.026485957,
#                'PHASE4': 0.01992568,
#                'organization_class_INDUSTRY': 0.031299323,
#                'organization_class_OTHER': 0.01760144,
#                'oversightHasDmc_no': 0.013763162,
#                'oversightHasDmc_yes': 0.020476004,
#                'FdaRegulatedDrug_yes': 0.077521235,
#                'FdaRegulatedDevice_no': 0.020341787,
#                'FdaRegulatedDevice_yes': 0.036382716,
#                'interventionModel_CROSSOVER': 0.0338736,
#                'interventionModel_PARALLEL': 0.043927778,
#                'primaryPurpose_DIAGNOSTIC': 0.0177489,
#                'masking_SINGLE': 0.022597564,
#                'healthyVolunteers_no': 0.07664536,
#                'healthyVolunteers_yes': 0.078631796,
#                'duration_of_trial': 0.036039725,
#                'facility_count': 0.029039444,
#                'Neoplasms': 0.037270557,
#                'collaborator_NIH': 0.018495405,
#                'Organic Chemicals': 0.015772441},
#               {'eligibilityModule_maximumAge': 0.017275127,
#                'designModule_enrollmentInfo_count': 0.23189174,
#                'leadsponsor_INDUSTRY': 0.024432605,
#                'PHASE2': 0.02292997,
#                'PHASE3': 0.023323067,
#                'organization_class_INDUSTRY': 0.033511043,
#                'oversightHasDmc_yes': 0.020062305,
#                'FdaRegulatedDrug_no': 0.02322955,
#                'FdaRegulatedDrug_yes': 0.06526981,
#                'FdaRegulatedDevice_no': 0.02150342,
#                'interventionModel_CROSSOVER': 0.029568354,
#                'interventionModel_PARALLEL': 0.0429417,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.018222116,
#                'masking_SINGLE': 0.021456517,
#                'healthyVolunteers_no': 0.044781845,
#                'healthyVolunteers_yes': 0.17323942,
#                'sex_male': 0.020267325,
#                'restrictiveAgreement_yes': 0.018391136,
#                'duration_of_trial': 0.036371123,
#                'facility_count': 0.03131815,
#                'Infections': 0.019345397,
#                'Neoplasms': 0.03851631,
#                'collaborator_NIH': 0.022151906}],
#              'with_emb_auc': [0.8930703392845819,
#               0.8928908757744034,
#               0.8861282585747197,
#               0.8964095632169721,
#               0.8936046922585349],
#              'with_emb_precision': [0.7722110888443554,
#               0.7742514298530896,
#               0.7640845070422535,
#               0.776682719229477,
#               0.7764177428411005],
#              'with_emb_recall': [0.8685199098422239,
#               0.8645128975707488,
#               0.8695216629100927,
#               0.8683946907087403,
#               0.8657650889055848],
#              'with_emb_accuracy': [0.8061607813673929,
#               0.8062233909341348,
#               0.8005259203606311,
#               0.8093538692712247,
#               0.8082268970698723],
#              'with_emb_f1': [0.8175388967468176,
#               0.8168964089214932,
#               0.813400491976104,
#               0.8199822642624889,
#               0.8186608252915754],
#              'with_emb_tp': [6936, 6904, 6944, 6935, 6914],
#              'with_emb_tn': [5940, 5973, 5842, 5992, 5995],
#              'with_emb_fp': [2046, 2013, 2144, 1994, 1991],
#              'with_emb_fn': [1050, 1082, 1042, 1051, 1072],
#              'with_emb_report': [{'0': {'precision': 0.8497854077253219,
#                 'recall': 0.743801652892562,
#                 'f1-score': 0.7932692307692307,
#                 'support': 7986.0},
#                '1': {'precision': 0.7722110888443554,
#                 'recall': 0.8685199098422239,
#                 'f1-score': 0.8175388967468176,
#                 'support': 7986.0},
#                'accuracy': 0.8061607813673929,
#                'macro avg': {'precision': 0.8109982482848386,
#                 'recall': 0.806160781367393,
#                 'f1-score': 0.8054040637580242,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8109982482848386,
#                 'recall': 0.8061607813673929,
#                 'f1-score': 0.8054040637580242,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8466335931963147,
#                 'recall': 0.7479338842975206,
#                 'f1-score': 0.7942291071072403,
#                 'support': 7986.0},
#                '1': {'precision': 0.7742514298530896,
#                 'recall': 0.8645128975707488,
#                 'f1-score': 0.8168964089214932,
#                 'support': 7986.0},
#                'accuracy': 0.8062233909341348,
#                'macro avg': {'precision': 0.8104425115247021,
#                 'recall': 0.8062233909341348,
#                 'f1-score': 0.8055627580143667,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8104425115247021,
#                 'recall': 0.8062233909341348,
#                 'f1-score': 0.8055627580143667,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8486345148169668,
#                 'recall': 0.7315301778111696,
#                 'f1-score': 0.785743106926698,
#                 'support': 7986.0},
#                '1': {'precision': 0.7640845070422535,
#                 'recall': 0.8695216629100927,
#                 'f1-score': 0.813400491976104,
#                 'support': 7986.0},
#                'accuracy': 0.8005259203606311,
#                'macro avg': {'precision': 0.8063595109296102,
#                 'recall': 0.8005259203606312,
#                 'f1-score': 0.799571799451401,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8063595109296101,
#                 'recall': 0.8005259203606311,
#                 'f1-score': 0.799571799451401,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8507738179752946,
#                 'recall': 0.750313047833709,
#                 'f1-score': 0.7973917093619003,
#                 'support': 7986.0},
#                '1': {'precision': 0.776682719229477,
#                 'recall': 0.8683946907087403,
#                 'f1-score': 0.8199822642624889,
#                 'support': 7986.0},
#                'accuracy': 0.8093538692712247,
#                'macro avg': {'precision': 0.8137282686023858,
#                 'recall': 0.8093538692712247,
#                 'f1-score': 0.8086869868121946,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8137282686023858,
#                 'recall': 0.8093538692712247,
#                 'f1-score': 0.8086869868121946,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8483090420263195,
#                 'recall': 0.7506887052341598,
#                 'f1-score': 0.7965189663190062,
#                 'support': 7986.0},
#                '1': {'precision': 0.7764177428411005,
#                 'recall': 0.8657650889055848,
#                 'f1-score': 0.8186608252915754,
#                 'support': 7986.0},
#                'accuracy': 0.8082268970698723,
#                'macro avg': {'precision': 0.81236339243371,
#                 'recall': 0.8082268970698723,
#                 'f1-score': 0.8075898958052907,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.81236339243371,
#                 'recall': 0.8082268970698723,
#                 'f1-score': 0.8075898958052908,
#                 'support': 15972.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.8441803159878243,
#                 'recall': 0.7292762334084648,
#                 'f1-score': 0.7825327510917031,
#                 'support': 7986.0},
#                '1': {'precision': 0.7617105698225505,
#                 'recall': 0.865389431505134,
#                 'f1-score': 0.8102467905504426,
#                 'support': 7986.0},
#                'accuracy': 0.7973328324567994,
#                'macro avg': {'precision': 0.8029454429051874,
#                 'recall': 0.7973328324567994,
#                 'f1-score': 0.7963897708210728,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8029454429051873,
#                 'recall': 0.7973328324567994,
#                 'f1-score': 0.7963897708210728,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8510451688349656,
#                 'recall': 0.7290257951414976,
#                 'f1-score': 0.7853240709516423,
#                 'support': 7986.0},
#                '1': {'precision': 0.7630051473004053,
#                 'recall': 0.8724017029802154,
#                 'f1-score': 0.8140445171466962,
#                 'support': 7986.0},
#                'accuracy': 0.8007137490608565,
#                'macro avg': {'precision': 0.8070251580676855,
#                 'recall': 0.8007137490608565,
#                 'f1-score': 0.7996842940491693,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8070251580676855,
#                 'recall': 0.8007137490608565,
#                 'f1-score': 0.7996842940491693,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8480789047548948,
#                 'recall': 0.7213874279989982,
#                 'f1-score': 0.7796197306989647,
#                 'support': 7986.0},
#                '1': {'precision': 0.7575988669789737,
#                 'recall': 0.8707738542449286,
#                 'f1-score': 0.8102534226623944,
#                 'support': 7986.0},
#                'accuracy': 0.7960806411219634,
#                'macro avg': {'precision': 0.8028388858669342,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.7949365766806795,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8028388858669342,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.7949365766806795,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8529497239174658,
#                 'recall': 0.7350363135487102,
#                 'f1-score': 0.7896152811407049,
#                 'support': 7986.0},
#                '1': {'precision': 0.7672167216721673,
#                 'recall': 0.8732782369146006,
#                 'f1-score': 0.8168189271492152,
#                 'support': 7986.0},
#                'accuracy': 0.8041572752316554,
#                'macro avg': {'precision': 0.8100832227948165,
#                 'recall': 0.8041572752316555,
#                 'f1-score': 0.8032171041449601,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8100832227948165,
#                 'recall': 0.8041572752316554,
#                 'f1-score': 0.8032171041449601,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8447528187337381,
#                 'recall': 0.7317806160781367,
#                 'f1-score': 0.784219001610306,
#                 'support': 7986.0},
#                '1': {'precision': 0.7634194831013916,
#                 'recall': 0.8655146506386175,
#                 'f1-score': 0.8112676056338028,
#                 'support': 7986.0},
#                'accuracy': 0.7986476333583772,
#                'macro avg': {'precision': 0.8040861509175649,
#                 'recall': 0.7986476333583772,
#                 'f1-score': 0.7977433036220545,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8040861509175649,
#                 'recall': 0.7986476333583772,
#                 'f1-score': 0.7977433036220544,
#                 'support': 15972.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8497854077253219,
#                 'recall': 0.743801652892562,
#                 'f1-score': 0.7932692307692307,
#                 'support': 7986.0},
#                '1': {'precision': 0.7722110888443554,
#                 'recall': 0.8685199098422239,
#                 'f1-score': 0.8175388967468176,
#                 'support': 7986.0},
#                'accuracy': 0.8061607813673929,
#                'macro avg': {'precision': 0.8109982482848386,
#                 'recall': 0.806160781367393,
#                 'f1-score': 0.8054040637580242,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8109982482848386,
#                 'recall': 0.8061607813673929,
#                 'f1-score': 0.8054040637580242,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8466335931963147,
#                 'recall': 0.7479338842975206,
#                 'f1-score': 0.7942291071072403,
#                 'support': 7986.0},
#                '1': {'precision': 0.7742514298530896,
#                 'recall': 0.8645128975707488,
#                 'f1-score': 0.8168964089214932,
#                 'support': 7986.0},
#                'accuracy': 0.8062233909341348,
#                'macro avg': {'precision': 0.8104425115247021,
#                 'recall': 0.8062233909341348,
#                 'f1-score': 0.8055627580143667,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8104425115247021,
#                 'recall': 0.8062233909341348,
#                 'f1-score': 0.8055627580143667,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8486345148169668,
#                 'recall': 0.7315301778111696,
#                 'f1-score': 0.785743106926698,
#                 'support': 7986.0},
#                '1': {'precision': 0.7640845070422535,
#                 'recall': 0.8695216629100927,
#                 'f1-score': 0.813400491976104,
#                 'support': 7986.0},
#                'accuracy': 0.8005259203606311,
#                'macro avg': {'precision': 0.8063595109296102,
#                 'recall': 0.8005259203606312,
#                 'f1-score': 0.799571799451401,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8063595109296101,
#                 'recall': 0.8005259203606311,
#                 'f1-score': 0.799571799451401,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8507738179752946,
#                 'recall': 0.750313047833709,
#                 'f1-score': 0.7973917093619003,
#                 'support': 7986.0},
#                '1': {'precision': 0.776682719229477,
#                 'recall': 0.8683946907087403,
#                 'f1-score': 0.8199822642624889,
#                 'support': 7986.0},
#                'accuracy': 0.8093538692712247,
#                'macro avg': {'precision': 0.8137282686023858,
#                 'recall': 0.8093538692712247,
#                 'f1-score': 0.8086869868121946,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8137282686023858,
#                 'recall': 0.8093538692712247,
#                 'f1-score': 0.8086869868121946,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8483090420263195,
#                 'recall': 0.7506887052341598,
#                 'f1-score': 0.7965189663190062,
#                 'support': 7986.0},
#                '1': {'precision': 0.7764177428411005,
#                 'recall': 0.8657650889055848,
#                 'f1-score': 0.8186608252915754,
#                 'support': 7986.0},
#                'accuracy': 0.8082268970698723,
#                'macro avg': {'precision': 0.81236339243371,
#                 'recall': 0.8082268970698723,
#                 'f1-score': 0.8075898958052907,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.81236339243371,
#                 'recall': 0.8082268970698723,
#                 'f1-score': 0.8075898958052908,
#                 'support': 15972.0}}]})

# %%
from sklearn.metrics import classification_report
# === CONFIG ===
n_runs = 5
desired_ratio = 1.5
param_grid = {
    'n_estimators': [300, 400, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.2],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8]
}

# === RESULTS STORAGE ===
results = defaultdict(list)

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.05, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

    def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
        clf = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)
        grid = GridSearchCV(clf, param_grid, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)
        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        print(f"Best parameters for this run: {grid.best_params_}")
        y_pred = best_model.predict(X_test)
        y_prob = best_model.predict_proba(X_test)[:, 1]

        auc = roc_auc_score(y_test, y_prob)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # <-- Add classification report here
        report = classification_report(y_test, y_pred, output_dict=True)

        result = {
            'auc': auc,
            'precision': precision,
            'recall': recall,
            'accuracy': accuracy,
            'f1': f1,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'report': report  
        }

        if return_importance and feature_names is not None:
            importances = best_model.feature_importances_
            feature_importance_dict = dict(zip(feature_names, importances))
            result['feature_importance'] = feature_importance_dict

        return result

    # === Train and Evaluate ===
    # Pass selected feature names after feature selection
    metrics_no_emb = train_and_eval_all(
        X_train_sel, y_train, X_test_sel, y_test,
        feature_names=selected_feature_names,
        return_importance=True
    )

    metrics_with_emb = train_and_eval_all(
        X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
    results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

    # Save metrics to results
    for metric, value in metrics_no_emb.items():
        results[f'no_emb_{metric}'].append(value)
    for metric, value in metrics_with_emb.items():
        results[f'with_emb_{metric}'].append(value)
    
    results['no_emb_reports'].append(metrics_no_emb['report'])
    results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===

print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# ===================== Run 1/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 2/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 3/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 4/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 5/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.2738
# healthyVolunteers_no: 0.0944
# healthyVolunteers_yes: 0.0943
# FdaRegulatedDrug_yes: 0.0637
# interventionModel_PARALLEL: 0.0496
# Neoplasms: 0.0476
# duration_of_trial: 0.0371
# organization_class_INDUSTRY: 0.0355
# facility_count: 0.0336
# interventionModel_CROSSOVER: 0.0328
# FdaRegulatedDevice_yes: 0.0324
# PHASE3: 0.0265
# FdaRegulatedDrug_no: 0.0263
# PHASE2: 0.0249
# FdaRegulatedDevice_no: 0.0249
# interventionModel_SINGLE_GROUP: 0.0243
# interventionModel_SEQUENTIAL: 0.0234
# piSponsorEmployee_yes: 0.0233
# leadsponsor_INDUSTRY: 0.0227
# primaryPurpose_HEALTH_SERVICES_RESEARCH: 0.0217
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.86 ± 0.00  0.66 ± 0.01  0.75 ± 0.00   7986.00 ± 0.00
# 1     1  0.80 ± 0.00  0.93 ± 0.00  0.86 ± 0.00  11979.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.87 ± 0.00  0.68 ± 0.00  0.76 ± 0.00   7986.00 ± 0.00
# 1     1  0.81 ± 0.00  0.93 ± 0.00  0.87 ± 0.00  11979.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.01644414,
#                'designModule_enrollmentInfo_count': 0.29337928,
#                'PHASE2': 0.023827525,
#                'PHASE3': 0.02721443,
#                'PHASE4': 0.018279687,
#                'organization_class_INDUSTRY': 0.031009821,
#                'oversightHasDmc_no': 0.01442722,
#                'oversightHasDmc_yes': 0.022572191,
#                'FdaRegulatedDrug_no': 0.02236405,
#                'FdaRegulatedDrug_yes': 0.072984755,
#                'FdaRegulatedDevice_no': 0.025595173,
#                'interventionModel_CROSSOVER': 0.033931755,
#                'interventionModel_PARALLEL': 0.049028024,
#                'healthyVolunteers_no': 0.10487092,
#                'healthyVolunteers_yes': 0.08691257,
#                'duration_of_trial': 0.038068376,
#                'facility_count': 0.03279878,
#                'Neoplasms': 0.047984026,
#                'Respiratory Tract Diseases': 0.017451027,
#                'collaborator_NIH': 0.020856235},
#               {'eligibilityModule_maximumAge': 0.017003914,
#                'designModule_enrollmentInfo_count': 0.27780268,
#                'PHASE2': 0.024277687,
#                'PHASE3': 0.023641,
#                'organization_class_INDUSTRY': 0.029525675,
#                'oversightHasDmc_yes': 0.020227402,
#                'FdaRegulatedDrug_no': 0.02770086,
#                'FdaRegulatedDrug_yes': 0.067842305,
#                'interventionModel_CROSSOVER': 0.03523227,
#                'interventionModel_PARALLEL': 0.04675354,
#                'interventionModel_SEQUENTIAL': 0.022054326,
#                'interventionModel_SINGLE_GROUP': 0.024343088,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.02172663,
#                'masking_SINGLE': 0.023856029,
#                'healthyVolunteers_no': 0.09009443,
#                'healthyVolunteers_yes': 0.09640187,
#                'sex_male': 0.017062413,
#                'duration_of_trial': 0.038329966,
#                'facility_count': 0.033903718,
#                'Neoplasms': 0.04666217,
#                'Organic Chemicals': 0.015558105},
#               {'eligibilityModule_minimumAge': 0.018179456,
#                'eligibilityModule_maximumAge': 0.018573673,
#                'designModule_enrollmentInfo_count': 0.23282047,
#                'leadsponsor_INDUSTRY': 0.023191985,
#                'PHASE2': 0.028265515,
#                'PHASE3': 0.02730035,
#                'PHASE4': 0.021559896,
#                'organization_class_INDUSTRY': 0.041163,
#                'oversightHasDmc_yes': 0.02184224,
#                'FdaRegulatedDrug_no': 0.028301941,
#                'FdaRegulatedDrug_yes': 0.051519115,
#                'FdaRegulatedDevice_yes': 0.03243661,
#                'interventionModel_CROSSOVER': 0.030196287,
#                'interventionModel_PARALLEL': 0.05011245,
#                'primaryPurpose_DIAGNOSTIC': 0.020696372,
#                'masking_SINGLE': 0.0197488,
#                'healthyVolunteers_no': 0.06988493,
#                'healthyVolunteers_yes': 0.10641591,
#                'piSponsorEmployee_yes': 0.023253014,
#                'duration_of_trial': 0.03575676,
#                'facility_count': 0.03608486,
#                'Neoplasms': 0.043395817,
#                'Respiratory Tract Diseases': 0.019300425},
#               {'eligibilityModule_maximumAge': 0.01631709,
#                'designModule_enrollmentInfo_count': 0.30138698,
#                'leadsponsor_INDUSTRY': 0.022269616,
#                'PHASE2': 0.02193324,
#                'PHASE3': 0.026513593,
#                'organization_class_INDUSTRY': 0.043429524,
#                'oversightHasDmc_yes': 0.019235615,
#                'FdaRegulatedDrug_no': 0.02709975,
#                'FdaRegulatedDrug_yes': 0.06486667,
#                'FdaRegulatedDevice_no': 0.022132423,
#                'interventionModel_CROSSOVER': 0.029202335,
#                'interventionModel_PARALLEL': 0.051751424,
#                'interventionModel_SEQUENTIAL': 0.024743784,
#                'masking_SINGLE': 0.01912591,
#                'healthyVolunteers_no': 0.091073155,
#                'healthyVolunteers_yes': 0.1077437,
#                'duration_of_trial': 0.035381634,
#                'facility_count': 0.03274061,
#                'Neoplasms': 0.043052953},
#               {'eligibilityModule_maximumAge': 0.016245572,
#                'designModule_enrollmentInfo_count': 0.26337743,
#                'PHASE2': 0.026432056,
#                'PHASE3': 0.027616708,
#                'organization_class_INDUSTRY': 0.032367848,
#                'organization_class_OTHER': 0.015914999,
#                'oversightHasDmc_yes': 0.022912497,
#                'FdaRegulatedDrug_no': 0.026197761,
#                'FdaRegulatedDrug_yes': 0.061160635,
#                'FdaRegulatedDevice_no': 0.026898017,
#                'interventionModel_CROSSOVER': 0.03529435,
#                'interventionModel_PARALLEL': 0.05038597,
#                'masking_SINGLE': 0.023768753,
#                'healthyVolunteers_no': 0.11607839,
#                'healthyVolunteers_yes': 0.07422836,
#                'sex_male': 0.020473614,
#                'duration_of_trial': 0.037771385,
#                'facility_count': 0.03269085,
#                'Infections': 0.018174458,
#                'Neoplasms': 0.05689821,
#                'Respiratory Tract Diseases': 0.015112109}],
#              'no_emb_auc': [0.8824887214450148,
#               0.8820796346440398,
#               0.8842158810057178,
#               0.8816012900278132,
#               0.884420105582967],
#              'no_emb_precision': [0.8043164429045763,
#               0.8046598860275553,
#               0.8097287047841307,
#               0.8009322337755468,
#               0.8042608885334109],
#              'no_emb_recall': [0.9302112029384757,
#               0.9312129560063445,
#               0.9268720260455797,
#               0.932381667918858,
#               0.9233658903080391],
#              'no_emb_accuracy': [0.8223390934134736,
#               0.8230904082143752,
#               0.8254445279238668,
#               0.8203856749311295,
#               0.819183571249687],
#              'no_emb_f1': [0.8626950025161615,
#               0.8633232721925548,
#               0.8643493830524308,
#               0.8616725813917605,
#               0.8597077568785948],
#              'no_emb_tp': [11143, 11155, 11103, 11169, 11061],
#              'no_emb_tn': [5275, 5278, 5377, 5210, 5294],
#              'no_emb_fp': [2711, 2708, 2609, 2776, 2692],
#              'no_emb_fn': [836, 824, 876, 810, 918],
#              'no_emb_report': [{'0': {'precision': 0.8631975126820488,
#                 'recall': 0.6605309291259704,
#                 'f1-score': 0.7483861814570476,
#                 'support': 7986.0},
#                '1': {'precision': 0.8043164429045763,
#                 'recall': 0.9302112029384757,
#                 'f1-score': 0.8626950025161615,
#                 'support': 11979.0},
#                'accuracy': 0.8223390934134736,
#                'macro avg': {'precision': 0.8337569777933125,
#                 'recall': 0.7953710660322231,
#                 'f1-score': 0.8055405919866045,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8278688708155651,
#                 'recall': 0.8223390934134736,
#                 'f1-score': 0.8169714740925159,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8649623074401835,
#                 'recall': 0.6609065865264212,
#                 'f1-score': 0.749290176036343,
#                 'support': 7986.0},
#                '1': {'precision': 0.8046598860275553,
#                 'recall': 0.9312129560063445,
#                 'f1-score': 0.8633232721925548,
#                 'support': 11979.0},
#                'accuracy': 0.8230904082143752,
#                'macro avg': {'precision': 0.8348110967338694,
#                 'recall': 0.7960597712663828,
#                 'f1-score': 0.8063067241144488,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8287808545926066,
#                 'recall': 0.8230904082143752,
#                 'f1-score': 0.8177100337300701,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8599072445226291,
#                 'recall': 0.6733032807412973,
#                 'f1-score': 0.7552496664091579,
#                 'support': 7986.0},
#                '1': {'precision': 0.8097287047841307,
#                 'recall': 0.9268720260455797,
#                 'f1-score': 0.8643493830524308,
#                 'support': 11979.0},
#                'accuracy': 0.8254445279238668,
#                'macro avg': {'precision': 0.8348179746533799,
#                 'recall': 0.8000876533934385,
#                 'f1-score': 0.8097995247307943,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8298001206795302,
#                 'recall': 0.8254445279238668,
#                 'f1-score': 0.8207094963951217,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8654485049833887,
#                 'recall': 0.6523916854495367,
#                 'f1-score': 0.7439668713408539,
#                 'support': 7986.0},
#                '1': {'precision': 0.8009322337755468,
#                 'recall': 0.932381667918858,
#                 'f1-score': 0.8616725813917605,
#                 'support': 11979.0},
#                'accuracy': 0.8203856749311295,
#                'macro avg': {'precision': 0.8331903693794678,
#                 'recall': 0.7923866766841974,
#                 'f1-score': 0.8028197263663073,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8267387422586836,
#                 'recall': 0.8203856749311295,
#                 'f1-score': 0.8145902973713979,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8522215067611075,
#                 'recall': 0.6629100926621587,
#                 'f1-score': 0.7457388364558388,
#                 'support': 7986.0},
#                '1': {'precision': 0.8042608885334109,
#                 'recall': 0.9233658903080391,
#                 'f1-score': 0.8597077568785948,
#                 'support': 11979.0},
#                'accuracy': 0.819183571249687,
#                'macro avg': {'precision': 0.8282411976472592,
#                 'recall': 0.7931379914850989,
#                 'f1-score': 0.8027232966672169,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8234451358244896,
#                 'recall': 0.819183571249687,
#                 'f1-score': 0.8141201887094924,
#                 'support': 19965.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.01644414,
#                'designModule_enrollmentInfo_count': 0.29337928,
#                'PHASE2': 0.023827525,
#                'PHASE3': 0.02721443,
#                'PHASE4': 0.018279687,
#                'organization_class_INDUSTRY': 0.031009821,
#                'oversightHasDmc_no': 0.01442722,
#                'oversightHasDmc_yes': 0.022572191,
#                'FdaRegulatedDrug_no': 0.02236405,
#                'FdaRegulatedDrug_yes': 0.072984755,
#                'FdaRegulatedDevice_no': 0.025595173,
#                'interventionModel_CROSSOVER': 0.033931755,
#                'interventionModel_PARALLEL': 0.049028024,
#                'healthyVolunteers_no': 0.10487092,
#                'healthyVolunteers_yes': 0.08691257,
#                'duration_of_trial': 0.038068376,
#                'facility_count': 0.03279878,
#                'Neoplasms': 0.047984026,
#                'Respiratory Tract Diseases': 0.017451027,
#                'collaborator_NIH': 0.020856235},
#               {'eligibilityModule_maximumAge': 0.017003914,
#                'designModule_enrollmentInfo_count': 0.27780268,
#                'PHASE2': 0.024277687,
#                'PHASE3': 0.023641,
#                'organization_class_INDUSTRY': 0.029525675,
#                'oversightHasDmc_yes': 0.020227402,
#                'FdaRegulatedDrug_no': 0.02770086,
#                'FdaRegulatedDrug_yes': 0.067842305,
#                'interventionModel_CROSSOVER': 0.03523227,
#                'interventionModel_PARALLEL': 0.04675354,
#                'interventionModel_SEQUENTIAL': 0.022054326,
#                'interventionModel_SINGLE_GROUP': 0.024343088,
#                'primaryPurpose_HEALTH_SERVICES_RESEARCH': 0.02172663,
#                'masking_SINGLE': 0.023856029,
#                'healthyVolunteers_no': 0.09009443,
#                'healthyVolunteers_yes': 0.09640187,
#                'sex_male': 0.017062413,
#                'duration_of_trial': 0.038329966,
#                'facility_count': 0.033903718,
#                'Neoplasms': 0.04666217,
#                'Organic Chemicals': 0.015558105},
#               {'eligibilityModule_minimumAge': 0.018179456,
#                'eligibilityModule_maximumAge': 0.018573673,
#                'designModule_enrollmentInfo_count': 0.23282047,
#                'leadsponsor_INDUSTRY': 0.023191985,
#                'PHASE2': 0.028265515,
#                'PHASE3': 0.02730035,
#                'PHASE4': 0.021559896,
#                'organization_class_INDUSTRY': 0.041163,
#                'oversightHasDmc_yes': 0.02184224,
#                'FdaRegulatedDrug_no': 0.028301941,
#                'FdaRegulatedDrug_yes': 0.051519115,
#                'FdaRegulatedDevice_yes': 0.03243661,
#                'interventionModel_CROSSOVER': 0.030196287,
#                'interventionModel_PARALLEL': 0.05011245,
#                'primaryPurpose_DIAGNOSTIC': 0.020696372,
#                'masking_SINGLE': 0.0197488,
#                'healthyVolunteers_no': 0.06988493,
#                'healthyVolunteers_yes': 0.10641591,
#                'piSponsorEmployee_yes': 0.023253014,
#                'duration_of_trial': 0.03575676,
#                'facility_count': 0.03608486,
#                'Neoplasms': 0.043395817,
#                'Respiratory Tract Diseases': 0.019300425},
#               {'eligibilityModule_maximumAge': 0.01631709,
#                'designModule_enrollmentInfo_count': 0.30138698,
#                'leadsponsor_INDUSTRY': 0.022269616,
#                'PHASE2': 0.02193324,
#                'PHASE3': 0.026513593,
#                'organization_class_INDUSTRY': 0.043429524,
#                'oversightHasDmc_yes': 0.019235615,
#                'FdaRegulatedDrug_no': 0.02709975,
#                'FdaRegulatedDrug_yes': 0.06486667,
#                'FdaRegulatedDevice_no': 0.022132423,
#                'interventionModel_CROSSOVER': 0.029202335,
#                'interventionModel_PARALLEL': 0.051751424,
#                'interventionModel_SEQUENTIAL': 0.024743784,
#                'masking_SINGLE': 0.01912591,
#                'healthyVolunteers_no': 0.091073155,
#                'healthyVolunteers_yes': 0.1077437,
#                'duration_of_trial': 0.035381634,
#                'facility_count': 0.03274061,
#                'Neoplasms': 0.043052953},
#               {'eligibilityModule_maximumAge': 0.016245572,
#                'designModule_enrollmentInfo_count': 0.26337743,
#                'PHASE2': 0.026432056,
#                'PHASE3': 0.027616708,
#                'organization_class_INDUSTRY': 0.032367848,
#                'organization_class_OTHER': 0.015914999,
#                'oversightHasDmc_yes': 0.022912497,
#                'FdaRegulatedDrug_no': 0.026197761,
#                'FdaRegulatedDrug_yes': 0.061160635,
#                'FdaRegulatedDevice_no': 0.026898017,
#                'interventionModel_CROSSOVER': 0.03529435,
#                'interventionModel_PARALLEL': 0.05038597,
#                'masking_SINGLE': 0.023768753,
#                'healthyVolunteers_no': 0.11607839,
#                'healthyVolunteers_yes': 0.07422836,
#                'sex_male': 0.020473614,
#                'duration_of_trial': 0.037771385,
#                'facility_count': 0.03269085,
#                'Infections': 0.018174458,
#                'Neoplasms': 0.05689821,
#                'Respiratory Tract Diseases': 0.015112109}],
#              'with_emb_auc': [0.8924017930869799,
#               0.8941612583269574,
#               0.89467305325015,
#               0.8929425695651922,
#               0.8974780862335113],
#              'with_emb_precision': [0.8122989178122259,
#               0.8144502770487022,
#               0.8125637662148375,
#               0.8099760748205611,
#               0.8142489900844657],
#              'with_emb_recall': [0.9273729025795141,
#               0.9325486267635028,
#               0.9307955588947324,
#               0.9326321061858251,
#               0.925452875866099],
#              'with_emb_accuracy': [0.8278487352867518,
#               0.8320560981718007,
#               0.8296518908089155,
#               0.8282995241672928,
#               0.8286000500876534],
#              'with_emb_f1': [0.8660300136425648,
#               0.8695076863202957,
#               0.8676705186568616,
#               0.8669874282166693,
#               0.8662967883097601],
#              'with_emb_tp': [11109, 11171, 11150, 11172, 11086],
#              'with_emb_tn': [5419, 5441, 5414, 5365, 5457],
#              'with_emb_fp': [2567, 2545, 2572, 2621, 2529],
#              'with_emb_fn': [870, 808, 829, 807, 893],
#              'with_emb_report': [{'0': {'precision': 0.8616632214978533,
#                 'recall': 0.6785624843476084,
#                 'f1-score': 0.7592294220665499,
#                 'support': 7986.0},
#                '1': {'precision': 0.8122989178122259,
#                 'recall': 0.9273729025795141,
#                 'f1-score': 0.8660300136425648,
#                 'support': 11979.0},
#                'accuracy': 0.8278487352867518,
#                'macro avg': {'precision': 0.8369810696550396,
#                 'recall': 0.8029676934635612,
#                 'f1-score': 0.8126297178545574,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8320446392864769,
#                 'recall': 0.8278487352867518,
#                 'f1-score': 0.8233097770121587,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8706993118899023,
#                 'recall': 0.6813173052842474,
#                 'f1-score': 0.7644538110291534,
#                 'support': 7986.0},
#                '1': {'precision': 0.8144502770487022,
#                 'recall': 0.9325486267635028,
#                 'f1-score': 0.8695076863202957,
#                 'support': 11979.0},
#                'accuracy': 0.8320560981718007,
#                'macro avg': {'precision': 0.8425747944693023,
#                 'recall': 0.8069329660238751,
#                 'f1-score': 0.8169807486747246,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8369498909851822,
#                 'recall': 0.8320560981718007,
#                 'f1-score': 0.8274861362038388,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8672112766298254,
#                 'recall': 0.6779363886801903,
#                 'f1-score': 0.7609810949469393,
#                 'support': 7986.0},
#                '1': {'precision': 0.8125637662148375,
#                 'recall': 0.9307955588947324,
#                 'f1-score': 0.8676705186568616,
#                 'support': 11979.0},
#                'accuracy': 0.8296518908089155,
#                'macro avg': {'precision': 0.8398875214223315,
#                 'recall': 0.8043659737874613,
#                 'f1-score': 0.8143258068019005,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8344227703808328,
#                 'recall': 0.8296518908089155,
#                 'f1-score': 0.8249947491728926,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8692482177576151,
#                 'recall': 0.6718006511394942,
#                 'f1-score': 0.7578754061308094,
#                 'support': 7986.0},
#                '1': {'precision': 0.8099760748205611,
#                 'recall': 0.9326321061858251,
#                 'f1-score': 0.8669874282166693,
#                 'support': 11979.0},
#                'accuracy': 0.8282995241672928,
#                'macro avg': {'precision': 0.8396121462890881,
#                 'recall': 0.8022163786626597,
#                 'f1-score': 0.8124314171737393,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8336849319953827,
#                 'recall': 0.8282995241672928,
#                 'f1-score': 0.8233426193823254,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8593700787401575,
#                 'recall': 0.683320811419985,
#                 'f1-score': 0.7613002232142857,
#                 'support': 7986.0},
#                '1': {'precision': 0.8142489900844657,
#                 'recall': 0.925452875866099,
#                 'f1-score': 0.8662967883097601,
#                 'support': 11979.0},
#                'accuracy': 0.8286000500876534,
#                'macro avg': {'precision': 0.8368095344123117,
#                 'recall': 0.804386843643042,
#                 'f1-score': 0.813798505762023,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8322974255467425,
#                 'recall': 0.8286000500876534,
#                 'f1-score': 0.8242981622715704,
#                 'support': 19965.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.8631975126820488,
#                 'recall': 0.6605309291259704,
#                 'f1-score': 0.7483861814570476,
#                 'support': 7986.0},
#                '1': {'precision': 0.8043164429045763,
#                 'recall': 0.9302112029384757,
#                 'f1-score': 0.8626950025161615,
#                 'support': 11979.0},
#                'accuracy': 0.8223390934134736,
#                'macro avg': {'precision': 0.8337569777933125,
#                 'recall': 0.7953710660322231,
#                 'f1-score': 0.8055405919866045,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8278688708155651,
#                 'recall': 0.8223390934134736,
#                 'f1-score': 0.8169714740925159,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8649623074401835,
#                 'recall': 0.6609065865264212,
#                 'f1-score': 0.749290176036343,
#                 'support': 7986.0},
#                '1': {'precision': 0.8046598860275553,
#                 'recall': 0.9312129560063445,
#                 'f1-score': 0.8633232721925548,
#                 'support': 11979.0},
#                'accuracy': 0.8230904082143752,
#                'macro avg': {'precision': 0.8348110967338694,
#                 'recall': 0.7960597712663828,
#                 'f1-score': 0.8063067241144488,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8287808545926066,
#                 'recall': 0.8230904082143752,
#                 'f1-score': 0.8177100337300701,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8599072445226291,
#                 'recall': 0.6733032807412973,
#                 'f1-score': 0.7552496664091579,
#                 'support': 7986.0},
#                '1': {'precision': 0.8097287047841307,
#                 'recall': 0.9268720260455797,
#                 'f1-score': 0.8643493830524308,
#                 'support': 11979.0},
#                'accuracy': 0.8254445279238668,
#                'macro avg': {'precision': 0.8348179746533799,
#                 'recall': 0.8000876533934385,
#                 'f1-score': 0.8097995247307943,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8298001206795302,
#                 'recall': 0.8254445279238668,
#                 'f1-score': 0.8207094963951217,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8654485049833887,
#                 'recall': 0.6523916854495367,
#                 'f1-score': 0.7439668713408539,
#                 'support': 7986.0},
#                '1': {'precision': 0.8009322337755468,
#                 'recall': 0.932381667918858,
#                 'f1-score': 0.8616725813917605,
#                 'support': 11979.0},
#                'accuracy': 0.8203856749311295,
#                'macro avg': {'precision': 0.8331903693794678,
#                 'recall': 0.7923866766841974,
#                 'f1-score': 0.8028197263663073,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8267387422586836,
#                 'recall': 0.8203856749311295,
#                 'f1-score': 0.8145902973713979,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8522215067611075,
#                 'recall': 0.6629100926621587,
#                 'f1-score': 0.7457388364558388,
#                 'support': 7986.0},
#                '1': {'precision': 0.8042608885334109,
#                 'recall': 0.9233658903080391,
#                 'f1-score': 0.8597077568785948,
#                 'support': 11979.0},
#                'accuracy': 0.819183571249687,
#                'macro avg': {'precision': 0.8282411976472592,
#                 'recall': 0.7931379914850989,
#                 'f1-score': 0.8027232966672169,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8234451358244896,
#                 'recall': 0.819183571249687,
#                 'f1-score': 0.8141201887094924,
#                 'support': 19965.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8616632214978533,
#                 'recall': 0.6785624843476084,
#                 'f1-score': 0.7592294220665499,
#                 'support': 7986.0},
#                '1': {'precision': 0.8122989178122259,
#                 'recall': 0.9273729025795141,
#                 'f1-score': 0.8660300136425648,
#                 'support': 11979.0},
#                'accuracy': 0.8278487352867518,
#                'macro avg': {'precision': 0.8369810696550396,
#                 'recall': 0.8029676934635612,
#                 'f1-score': 0.8126297178545574,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8320446392864769,
#                 'recall': 0.8278487352867518,
#                 'f1-score': 0.8233097770121587,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8706993118899023,
#                 'recall': 0.6813173052842474,
#                 'f1-score': 0.7644538110291534,
#                 'support': 7986.0},
#                '1': {'precision': 0.8144502770487022,
#                 'recall': 0.9325486267635028,
#                 'f1-score': 0.8695076863202957,
#                 'support': 11979.0},
#                'accuracy': 0.8320560981718007,
#                'macro avg': {'precision': 0.8425747944693023,
#                 'recall': 0.8069329660238751,
#                 'f1-score': 0.8169807486747246,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8369498909851822,
#                 'recall': 0.8320560981718007,
#                 'f1-score': 0.8274861362038388,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8672112766298254,
#                 'recall': 0.6779363886801903,
#                 'f1-score': 0.7609810949469393,
#                 'support': 7986.0},
#                '1': {'precision': 0.8125637662148375,
#                 'recall': 0.9307955588947324,
#                 'f1-score': 0.8676705186568616,
#                 'support': 11979.0},
#                'accuracy': 0.8296518908089155,
#                'macro avg': {'precision': 0.8398875214223315,
#                 'recall': 0.8043659737874613,
#                 'f1-score': 0.8143258068019005,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8344227703808328,
#                 'recall': 0.8296518908089155,
#                 'f1-score': 0.8249947491728926,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8692482177576151,
#                 'recall': 0.6718006511394942,
#                 'f1-score': 0.7578754061308094,
#                 'support': 7986.0},
#                '1': {'precision': 0.8099760748205611,
#                 'recall': 0.9326321061858251,
#                 'f1-score': 0.8669874282166693,
#                 'support': 11979.0},
#                'accuracy': 0.8282995241672928,
#                'macro avg': {'precision': 0.8396121462890881,
#                 'recall': 0.8022163786626597,
#                 'f1-score': 0.8124314171737393,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8336849319953827,
#                 'recall': 0.8282995241672928,
#                 'f1-score': 0.8233426193823254,
#                 'support': 19965.0}},
#               {'0': {'precision': 0.8593700787401575,
#                 'recall': 0.683320811419985,
#                 'f1-score': 0.7613002232142857,
#                 'support': 7986.0},
#                '1': {'precision': 0.8142489900844657,
#                 'recall': 0.925452875866099,
#                 'f1-score': 0.8662967883097601,
#                 'support': 11979.0},
#                'accuracy': 0.8286000500876534,
#                'macro avg': {'precision': 0.8368095344123117,
#                 'recall': 0.804386843643042,
#                 'f1-score': 0.813798505762023,
#                 'support': 19965.0},
#                'weighted avg': {'precision': 0.8322974255467425,
#                 'recall': 0.8286000500876534,
#                 'f1-score': 0.8242981622715704,
#                 'support': 19965.0}}]})

# %%
# === CONFIG ===
n_runs = 5
desired_ratio = 2
param_grid = {
    'n_estimators': [300, 400, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1, 0.2],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8]
}

# === RESULTS STORAGE ===
results = defaultdict(list)

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.05, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

    def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
        clf = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)
        grid = GridSearchCV(clf, param_grid, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)
        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        print(f"Best parameters for this run: {grid.best_params_}")
        y_pred = best_model.predict(X_test)
        y_prob = best_model.predict_proba(X_test)[:, 1]

        auc = roc_auc_score(y_test, y_prob)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # <-- Add classification report here
        report = classification_report(y_test, y_pred, output_dict=True)

        result = {
            'auc': auc,
            'precision': precision,
            'recall': recall,
            'accuracy': accuracy,
            'f1': f1,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'report': report  
        }

        if return_importance and feature_names is not None:
            importances = best_model.feature_importances_
            feature_importance_dict = dict(zip(feature_names, importances))
            result['feature_importance'] = feature_importance_dict

        return result

    # === Train and Evaluate ===
    # Pass selected feature names after feature selection
    metrics_no_emb = train_and_eval_all(
        X_train_sel, y_train, X_test_sel, y_test,
        feature_names=selected_feature_names,
        return_importance=True
    )

    metrics_with_emb = train_and_eval_all(
        X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
    results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

    # Save metrics to results
    for metric, value in metrics_no_emb.items():
        results[f'no_emb_{metric}'].append(value)
    for metric, value in metrics_with_emb.items():
        results[f'with_emb_{metric}'].append(value)
    
    results['no_emb_reports'].append(metrics_no_emb['report'])
    results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===

print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# ===================== Run 1/3 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 2/3 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ===================== Run 3/3 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.2865
# healthyVolunteers_no: 0.0963
# healthyVolunteers_yes: 0.0848
# FdaRegulatedDrug_yes: 0.0657
# interventionModel_PARALLEL: 0.0522
# Neoplasms: 0.0475
# FdaRegulatedDevice_yes: 0.0387
# duration_of_trial: 0.0350
# interventionModel_CROSSOVER: 0.0349
# organization_class_INDUSTRY: 0.0334
# facility_count: 0.0308
# designInfo_allocation_RANDOMIZED: 0.0257
# PHASE2: 0.0240
# PHASE3: 0.0235
# oversightHasDmc_yes: 0.0217
# FdaRegulatedDevice_no: 0.0215
# leadsponsor_INDUSTRY: 0.0213
# FdaRegulatedDrug_no: 0.0201
# interventionModel_SEQUENTIAL: 0.0200
# primaryPurpose_DIAGNOSTIC: 0.0195
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.86 ± 0.00  0.62 ± 0.01  0.72 ± 0.00   7986.00 ± 0.00
# 1     1  0.83 ± 0.00  0.95 ± 0.00  0.89 ± 0.00  15972.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.87 ± 0.00  0.63 ± 0.01  0.73 ± 0.00   7986.00 ± 0.00
# 1     1  0.84 ± 0.00  0.95 ± 0.00  0.89 ± 0.00  15972.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.017590467,
#                'designModule_enrollmentInfo_count': 0.28743276,
#                'PHASE2': 0.024211343,
#                'PHASE3': 0.026360098,
#                'PHASE4': 0.018560467,
#                'organization_class_INDUSTRY': 0.029907247,
#                'oversightHasDmc_yes': 0.022006279,
#                'FdaRegulatedDrug_yes': 0.06474012,
#                'FdaRegulatedDevice_no': 0.020305378,
#                'FdaRegulatedDevice_yes': 0.03869102,
#                'designInfo_allocation_RANDOMIZED': 0.026385076,
#                'interventionModel_CROSSOVER': 0.03780738,
#                'interventionModel_PARALLEL': 0.048835423,
#                'healthyVolunteers_no': 0.11216473,
#                'healthyVolunteers_yes': 0.0741268,
#                'duration_of_trial': 0.03783811,
#                'facility_count': 0.033590637,
#                'Neoplasms': 0.04804359,
#                'Respiratory Tract Diseases': 0.016548503,
#                'Organic Chemicals': 0.014854645},
#               {'eligibilityModule_maximumAge': 0.012719328,
#                'designModule_enrollmentInfo_count': 0.30545622,
#                'leadsponsor_INDUSTRY': 0.019188877,
#                'PHASE2': 0.025767054,
#                'PHASE3': 0.019301688,
#                'organization_class_INDUSTRY': 0.038736086,
#                'organization_class_OTHER': 0.012679069,
#                'oversightHasDmc_yes': 0.020578641,
#                'FdaRegulatedDrug_no': 0.018312993,
#                'FdaRegulatedDrug_yes': 0.06888039,
#                'interventionModel_CROSSOVER': 0.027471574,
#                'interventionModel_PARALLEL': 0.056957677,
#                'interventionModel_SEQUENTIAL': 0.019960815,
#                'masking_SINGLE': 0.019388871,
#                'healthyVolunteers_no': 0.113804094,
#                'healthyVolunteers_yes': 0.07706661,
#                'sex_male': 0.011449566,
#                'duration_of_trial': 0.035321794,
#                'facility_count': 0.029047487,
#                'Neoplasms': 0.04458037,
#                'Immune System Diseases': 0.009363172,
#                'Organic Chemicals': 0.013967679},
#               {'eligibilityModule_minimumAge': 0.014805535,
#                'eligibilityModule_maximumAge': 0.0151627585,
#                'designModule_enrollmentInfo_count': 0.26659262,
#                'leadsponsor_INDUSTRY': 0.023439225,
#                'PHASE2': 0.022066165,
#                'PHASE3': 0.024764119,
#                'organization_class_INDUSTRY': 0.03161593,
#                'oversightHasDmc_no': 0.012136736,
#                'oversightHasDmc_yes': 0.022511533,
#                'FdaRegulatedDrug_no': 0.02180453,
#                'FdaRegulatedDrug_yes': 0.06347721,
#                'FdaRegulatedDevice_no': 0.022606969,
#                'designInfo_allocation_RANDOMIZED': 0.024980279,
#                'interventionModel_CROSSOVER': 0.039465874,
#                'interventionModel_PARALLEL': 0.05093217,
#                'primaryPurpose_DIAGNOSTIC': 0.01950387,
#                'masking_SINGLE': 0.016442336,
#                'healthyVolunteers_no': 0.062793106,
#                'healthyVolunteers_yes': 0.10325904,
#                'sex_male': 0.016131107,
#                'duration_of_trial': 0.031702787,
#                'facility_count': 0.02988745,
#                'Neoplasms': 0.049873043,
#                'Respiratory Tract Diseases': 0.014045596}],
#              'no_emb_auc': [0.8817916131278823,
#               0.8819129554230547,
#               0.8808926178350304],
#              'no_emb_precision': [0.8362211676415406,
#               0.8307920140412461,
#               0.8341051935163745],
#              'no_emb_recall': [0.9487853744052092,
#               0.9483471074380165,
#               0.9472201352366642],
#              'no_emb_accuracy': [0.8419734535437015,
#               0.8367977293597129,
#               0.8392186326070623],
#              'no_emb_f1': [0.8889540681644864,
#               0.885685884691849,
#               0.887071240105541],
#              'no_emb_tp': [15154, 15147, 15129],
#              'no_emb_tn': [5018, 4901, 4977],
#              'no_emb_fp': [2968, 3085, 3009],
#              'no_emb_fn': [818, 825, 843],
#              'no_emb_report': [{'0': {'precision': 0.8598355037697053,
#                 'recall': 0.6283496118206862,
#                 'f1-score': 0.7260888438720879,
#                 'support': 7986.0},
#                '1': {'precision': 0.8362211676415406,
#                 'recall': 0.9487853744052092,
#                 'f1-score': 0.8889540681644864,
#                 'support': 15972.0},
#                'accuracy': 0.8419734535437015,
#                'macro avg': {'precision': 0.848028335705623,
#                 'recall': 0.7885674931129476,
#                 'f1-score': 0.8075214560182872,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8440926130175955,
#                 'recall': 0.8419734535437015,
#                 'f1-score': 0.8346656600670203,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8559203632553266,
#                 'recall': 0.6136989732031054,
#                 'f1-score': 0.7148483080513419,
#                 'support': 7986.0},
#                '1': {'precision': 0.8307920140412461,
#                 'recall': 0.9483471074380165,
#                 'f1-score': 0.885685884691849,
#                 'support': 15972.0},
#                'accuracy': 0.8367977293597129,
#                'macro avg': {'precision': 0.8433561886482863,
#                 'recall': 0.7810230403205609,
#                 'f1-score': 0.8002670963715954,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8391681304459396,
#                 'recall': 0.8367977293597129,
#                 'f1-score': 0.8287400258116799,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8551546391752577,
#                 'recall': 0.6232156273478587,
#                 'f1-score': 0.7209908735332464,
#                 'support': 7986.0},
#                '1': {'precision': 0.8341051935163745,
#                 'recall': 0.9472201352366642,
#                 'f1-score': 0.887071240105541,
#                 'support': 15972.0},
#                'accuracy': 0.8392186326070623,
#                'macro avg': {'precision': 0.8446299163458161,
#                 'recall': 0.7852178812922614,
#                 'f1-score': 0.8040310568193937,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8411216754026689,
#                 'recall': 0.8392186326070623,
#                 'f1-score': 0.831711117914776,
#                 'support': 23958.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.017590467,
#                'designModule_enrollmentInfo_count': 0.28743276,
#                'PHASE2': 0.024211343,
#                'PHASE3': 0.026360098,
#                'PHASE4': 0.018560467,
#                'organization_class_INDUSTRY': 0.029907247,
#                'oversightHasDmc_yes': 0.022006279,
#                'FdaRegulatedDrug_yes': 0.06474012,
#                'FdaRegulatedDevice_no': 0.020305378,
#                'FdaRegulatedDevice_yes': 0.03869102,
#                'designInfo_allocation_RANDOMIZED': 0.026385076,
#                'interventionModel_CROSSOVER': 0.03780738,
#                'interventionModel_PARALLEL': 0.048835423,
#                'healthyVolunteers_no': 0.11216473,
#                'healthyVolunteers_yes': 0.0741268,
#                'duration_of_trial': 0.03783811,
#                'facility_count': 0.033590637,
#                'Neoplasms': 0.04804359,
#                'Respiratory Tract Diseases': 0.016548503,
#                'Organic Chemicals': 0.014854645},
#               {'eligibilityModule_maximumAge': 0.012719328,
#                'designModule_enrollmentInfo_count': 0.30545622,
#                'leadsponsor_INDUSTRY': 0.019188877,
#                'PHASE2': 0.025767054,
#                'PHASE3': 0.019301688,
#                'organization_class_INDUSTRY': 0.038736086,
#                'organization_class_OTHER': 0.012679069,
#                'oversightHasDmc_yes': 0.020578641,
#                'FdaRegulatedDrug_no': 0.018312993,
#                'FdaRegulatedDrug_yes': 0.06888039,
#                'interventionModel_CROSSOVER': 0.027471574,
#                'interventionModel_PARALLEL': 0.056957677,
#                'interventionModel_SEQUENTIAL': 0.019960815,
#                'masking_SINGLE': 0.019388871,
#                'healthyVolunteers_no': 0.113804094,
#                'healthyVolunteers_yes': 0.07706661,
#                'sex_male': 0.011449566,
#                'duration_of_trial': 0.035321794,
#                'facility_count': 0.029047487,
#                'Neoplasms': 0.04458037,
#                'Immune System Diseases': 0.009363172,
#                'Organic Chemicals': 0.013967679},
#               {'eligibilityModule_minimumAge': 0.014805535,
#                'eligibilityModule_maximumAge': 0.0151627585,
#                'designModule_enrollmentInfo_count': 0.26659262,
#                'leadsponsor_INDUSTRY': 0.023439225,
#                'PHASE2': 0.022066165,
#                'PHASE3': 0.024764119,
#                'organization_class_INDUSTRY': 0.03161593,
#                'oversightHasDmc_no': 0.012136736,
#                'oversightHasDmc_yes': 0.022511533,
#                'FdaRegulatedDrug_no': 0.02180453,
#                'FdaRegulatedDrug_yes': 0.06347721,
#                'FdaRegulatedDevice_no': 0.022606969,
#                'designInfo_allocation_RANDOMIZED': 0.024980279,
#                'interventionModel_CROSSOVER': 0.039465874,
#                'interventionModel_PARALLEL': 0.05093217,
#                'primaryPurpose_DIAGNOSTIC': 0.01950387,
#                'masking_SINGLE': 0.016442336,
#                'healthyVolunteers_no': 0.062793106,
#                'healthyVolunteers_yes': 0.10325904,
#                'sex_male': 0.016131107,
#                'duration_of_trial': 0.031702787,
#                'facility_count': 0.02988745,
#                'Neoplasms': 0.049873043,
#                'Respiratory Tract Diseases': 0.014045596}],
#              'with_emb_auc': [0.8930130255808922,
#               0.8941018056329355,
#               0.8897989423828288],
#              'with_emb_precision': [0.8414167729061582,
#               0.836149485387198,
#               0.8372683142100618],
#              'with_emb_recall': [0.9504132231404959,
#               0.9511645379413974,
#               0.9502880040070123],
#              'with_emb_accuracy': [0.8475248351281409,
#               0.8431839051673763,
#               0.8437265214124718],
#              'with_emb_f1': [0.8925998882780114,
#               0.8899563574587739,
#               0.8902052785923754],
#              'with_emb_tp': [15180, 15192, 15178],
#              'with_emb_tn': [5125, 5009, 5036],
#              'with_emb_fp': [2861, 2977, 2950],
#              'with_emb_fn': [792, 780, 794],
#              'with_emb_report': [{'0': {'precision': 0.8661483860064222,
#                 'recall': 0.641748059103431,
#                 'f1-score': 0.7372509530317197,
#                 'support': 7986.0},
#                '1': {'precision': 0.8414167729061582,
#                 'recall': 0.9504132231404959,
#                 'f1-score': 0.8925998882780114,
#                 'support': 15972.0},
#                'accuracy': 0.8475248351281409,
#                'macro avg': {'precision': 0.8537825794562902,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.8149254206548655,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8496606439395795,
#                 'recall': 0.8475248351281409,
#                 'f1-score': 0.8408169098625808,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8652617032302643,
#                 'recall': 0.6272226396193339,
#                 'f1-score': 0.7272595281306715,
#                 'support': 7986.0},
#                '1': {'precision': 0.836149485387198,
#                 'recall': 0.9511645379413974,
#                 'f1-score': 0.8899563574587739,
#                 'support': 15972.0},
#                'accuracy': 0.8431839051673763,
#                'macro avg': {'precision': 0.8507055943087312,
#                 'recall': 0.7891935887803656,
#                 'f1-score': 0.8086079427947227,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8458535580015534,
#                 'recall': 0.8431839051673763,
#                 'f1-score': 0.8357240810160731,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8638078902229845,
#                 'recall': 0.6306035562233909,
#                 'f1-score': 0.7290098436595251,
#                 'support': 7986.0},
#                '1': {'precision': 0.8372683142100618,
#                 'recall': 0.9502880040070123,
#                 'f1-score': 0.8902052785923754,
#                 'support': 15972.0},
#                'accuracy': 0.8437265214124718,
#                'macro avg': {'precision': 0.8505381022165232,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.8096075611259503,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8461148395477026,
#                 'recall': 0.8437265214124718,
#                 'f1-score': 0.8364734669480921,
#                 'support': 23958.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.8598355037697053,
#                 'recall': 0.6283496118206862,
#                 'f1-score': 0.7260888438720879,
#                 'support': 7986.0},
#                '1': {'precision': 0.8362211676415406,
#                 'recall': 0.9487853744052092,
#                 'f1-score': 0.8889540681644864,
#                 'support': 15972.0},
#                'accuracy': 0.8419734535437015,
#                'macro avg': {'precision': 0.848028335705623,
#                 'recall': 0.7885674931129476,
#                 'f1-score': 0.8075214560182872,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8440926130175955,
#                 'recall': 0.8419734535437015,
#                 'f1-score': 0.8346656600670203,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8559203632553266,
#                 'recall': 0.6136989732031054,
#                 'f1-score': 0.7148483080513419,
#                 'support': 7986.0},
#                '1': {'precision': 0.8307920140412461,
#                 'recall': 0.9483471074380165,
#                 'f1-score': 0.885685884691849,
#                 'support': 15972.0},
#                'accuracy': 0.8367977293597129,
#                'macro avg': {'precision': 0.8433561886482863,
#                 'recall': 0.7810230403205609,
#                 'f1-score': 0.8002670963715954,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8391681304459396,
#                 'recall': 0.8367977293597129,
#                 'f1-score': 0.8287400258116799,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8551546391752577,
#                 'recall': 0.6232156273478587,
#                 'f1-score': 0.7209908735332464,
#                 'support': 7986.0},
#                '1': {'precision': 0.8341051935163745,
#                 'recall': 0.9472201352366642,
#                 'f1-score': 0.887071240105541,
#                 'support': 15972.0},
#                'accuracy': 0.8392186326070623,
#                'macro avg': {'precision': 0.8446299163458161,
#                 'recall': 0.7852178812922614,
#                 'f1-score': 0.8040310568193937,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8411216754026689,
#                 'recall': 0.8392186326070623,
#                 'f1-score': 0.831711117914776,
#                 'support': 23958.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8661483860064222,
#                 'recall': 0.641748059103431,
#                 'f1-score': 0.7372509530317197,
#                 'support': 7986.0},
#                '1': {'precision': 0.8414167729061582,
#                 'recall': 0.9504132231404959,
#                 'f1-score': 0.8925998882780114,
#                 'support': 15972.0},
#                'accuracy': 0.8475248351281409,
#                'macro avg': {'precision': 0.8537825794562902,
#                 'recall': 0.7960806411219634,
#                 'f1-score': 0.8149254206548655,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8496606439395795,
#                 'recall': 0.8475248351281409,
#                 'f1-score': 0.8408169098625808,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8652617032302643,
#                 'recall': 0.6272226396193339,
#                 'f1-score': 0.7272595281306715,
#                 'support': 7986.0},
#                '1': {'precision': 0.836149485387198,
#                 'recall': 0.9511645379413974,
#                 'f1-score': 0.8899563574587739,
#                 'support': 15972.0},
#                'accuracy': 0.8431839051673763,
#                'macro avg': {'precision': 0.8507055943087312,
#                 'recall': 0.7891935887803656,
#                 'f1-score': 0.8086079427947227,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8458535580015534,
#                 'recall': 0.8431839051673763,
#                 'f1-score': 0.8357240810160731,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8638078902229845,
#                 'recall': 0.6306035562233909,
#                 'f1-score': 0.7290098436595251,
#                 'support': 7986.0},
#                '1': {'precision': 0.8372683142100618,
#                 'recall': 0.9502880040070123,
#                 'f1-score': 0.8902052785923754,
#                 'support': 15972.0},
#                'accuracy': 0.8437265214124718,
#                'macro avg': {'precision': 0.8505381022165232,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.8096075611259503,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8461148395477026,
#                 'recall': 0.8437265214124718,
#                 'f1-score': 0.8364734669480921,
#                 'support': 23958.0}}]})

# %%
n_runs = 5
desired_ratio = 2
# param_grid = {
#     'n_estimators': [300, 400, 500],
#     'max_depth': [4, 6, 8],
#     'learning_rate': [0.05, 0.1, 0.2],
#     'subsample': [0.7, 0.8],
#     'colsample_bytree': [0.7, 0.8]
# }

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.05, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names
        print("length of features:", len(selected_feature_names))
        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)
# Out:
# ===================== Run 1/5 =====================
# Optimal PCA components: 318
# length of features: 20
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# length of features: 93
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 2/5 =====================
# Optimal PCA components: 318
# length of features: 22
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# length of features: 94
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 3/5 =====================
# Optimal PCA components: 318
# length of features: 24
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# length of features: 104
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 4/5 =====================
# Optimal PCA components: 318
# length of features: 23
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# length of features: 95
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ===================== Run 5/5 =====================
# Optimal PCA components: 318
# length of features: 25
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# length of features: 103
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
print("1:1")
print(np.mean([22,24,29,25,23]), "+/-", np.std([22,24,29,25,23]))
print(np.mean([108, 104, 103, 112, 109]), "+/-", np.std([108, 104, 103, 112, 109]))
print("1:1.5")
print(np.mean([20,21,23,19,21]), "+/-", np.std([20,21,23,19,21]))
print(np.mean([104,97,94,102,107]), "+/-", np.std([104,97,94,102,107]))
print("1:2")
print(np.mean([20,22,24,23,25]), "+/-", np.std([20,22,24,23,25]))
print(np.mean([93,94,104,95,103]), "+/-", np.std([93,94,104,95,103]))
# Out:
# 1:1
# 24.6 +/- 2.4166091947189146
# 107.2 +/- 3.3105890714493698
# 1:1.5
# 20.8 +/- 1.3266499161421599
# 100.8 +/- 4.707440918375928
# 1:2
# 22.8 +/- 1.7204650534085253
# 97.8 +/- 4.707440918375928

# %%
# Random forest (downsample)

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# === CONFIG ===
n_runs = 5
desired_ratio = 1
param_grid_rf = {
    'n_estimators': [400, 500, 600],
    'max_depth': [15, 20, 30],
    # 'max_features': ['sqrt', 'log2']
}

# === RESULTS STORAGE ===
results = defaultdict(list)

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

    def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
        clf = RandomForestClassifier(random_state=42)
        grid = GridSearchCV(clf, param_grid_rf, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)

        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        print(f"Best parameters for this run: {grid.best_params_}")
        y_pred = best_model.predict(X_test)
        y_prob = best_model.predict_proba(X_test)[:, 1]

        auc = roc_auc_score(y_test, y_prob)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # <-- Add classification report here
        report = classification_report(y_test, y_pred, output_dict=True)

        result = {
            'auc': auc,
            'precision': precision,
            'recall': recall,
            'accuracy': accuracy,
            'f1': f1,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'report': report  
        }

        if return_importance and feature_names is not None:
            importances = best_model.feature_importances_
            feature_importance_dict = dict(zip(feature_names, importances))
            result['feature_importance'] = feature_importance_dict

        return result

    # === Train and Evaluate ===
    # Pass selected feature names after feature selection
    metrics_no_emb = train_and_eval_all(
        X_train_sel, y_train, X_test_sel, y_test,
        feature_names=selected_feature_names,
        return_importance=True
    )

    metrics_with_emb = train_and_eval_all(
        X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
    results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

    # Save metrics to results
    for metric, value in metrics_no_emb.items():
        results[f'no_emb_{metric}'].append(value)
    for metric, value in metrics_with_emb.items():
        results[f'with_emb_{metric}'].append(value)
    
    results['no_emb_reports'].append(metrics_no_emb['report'])
    results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===

print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# ===================== Run 1/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Run 2/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 400}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Run 3/5 =====================
# Optimal PCA components: 317
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Run 4/5 =====================
# Optimal PCA components: 317
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Run 5/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.5675
# duration_of_trial: 0.1098
# facility_count: 0.0519
# exclusion_count: 0.0443
# eligibilityModule_maximumAge: 0.0432
# inclusion_count: 0.0410
# eligibilityModule_minimumAge: 0.0329
# healthyVolunteers_no: 0.0245
# FdaRegulatedDrug_yes: 0.0241
# healthyVolunteers_yes: 0.0224
# Neoplasms: 0.0171
# PHASE2: 0.0144
# masking_NONE: 0.0123
# FdaRegulatedDevice_no: 0.0115
# oversightHasDmc_yes: 0.0114
# primaryPurpose_TREATMENT: 0.0099
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score         support
# 0     0  0.85 ± 0.01  0.70 ± 0.00  0.76 ± 0.00  7986.00 ± 0.00
# 1     1  0.74 ± 0.00  0.87 ± 0.01  0.80 ± 0.00  7986.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score         support
# 0     0  0.85 ± 0.00  0.71 ± 0.00  0.78 ± 0.00  7986.00 ± 0.00
# 1     1  0.75 ± 0.00  0.88 ± 0.00  0.81 ± 0.00  7986.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.04444847212317863,
#                'designModule_enrollmentInfo_count': 0.5811480312303777,
#                'PHASE2': 0.014106096300136829,
#                'FdaRegulatedDrug_yes': 0.02473933431637326,
#                'healthyVolunteers_no': 0.02441994108775901,
#                'healthyVolunteers_yes': 0.024710433256953674,
#                'duration_of_trial': 0.12193405826683373,
#                'inclusion_count': 0.04334425162150246,
#                'exclusion_count': 0.04680718311334513,
#                'facility_count': 0.055566435536414424,
#                'Neoplasms': 0.018775763147125292},
#               {'eligibilityModule_minimumAge': 0.032435590424891754,
#                'eligibilityModule_maximumAge': 0.04103621745814229,
#                'designModule_enrollmentInfo_count': 0.5602789962658029,
#                'PHASE2': 0.01416904871790621,
#                'oversightHasDmc_yes': 0.011393527610475,
#                'FdaRegulatedDrug_yes': 0.023081847564837617,
#                'FdaRegulatedDevice_no': 0.011547004380257736,
#                'primaryPurpose_TREATMENT': 0.010098218948643439,
#                'healthyVolunteers_no': 0.022464314168165887,
#                'healthyVolunteers_yes': 0.022450346743536978,
#                'duration_of_trial': 0.10216192123475314,
#                'inclusion_count': 0.03965054447850096,
#                'exclusion_count': 0.042049728599605145,
#                'facility_count': 0.049432800138437885,
#                'Neoplasms': 0.01774989326604309},
#               {'eligibilityModule_maximumAge': 0.04477868777255475,
#                'designModule_enrollmentInfo_count': 0.5772818481954142,
#                'PHASE2': 0.014704236657502284,
#                'FdaRegulatedDrug_yes': 0.025688178320319374,
#                'FdaRegulatedDevice_no': 0.011471266783595566,
#                'healthyVolunteers_no': 0.02840592207931992,
#                'healthyVolunteers_yes': 0.021472202609959464,
#                'duration_of_trial': 0.117516383782168,
#                'inclusion_count': 0.04273382027773446,
#                'exclusion_count': 0.04689049918021706,
#                'facility_count': 0.05415246839396357,
#                'Neoplasms': 0.01490448594725135},
#               {'eligibilityModule_minimumAge': 0.03311642803676148,
#                'eligibilityModule_maximumAge': 0.042287294741095785,
#                'designModule_enrollmentInfo_count': 0.5568117699105252,
#                'PHASE2': 0.014301829799908284,
#                'FdaRegulatedDrug_yes': 0.023777043171813592,
#                'FdaRegulatedDevice_no': 0.011629925396355741,
#                'primaryPurpose_TREATMENT': 0.010072734656062565,
#                'masking_NONE': 0.012453278649851868,
#                'healthyVolunteers_no': 0.022506078953177352,
#                'healthyVolunteers_yes': 0.02077427758224579,
#                'duration_of_trial': 0.10378168657634033,
#                'inclusion_count': 0.039736604763412,
#                'exclusion_count': 0.04309837361812875,
#                'facility_count': 0.0493013624628057,
#                'Neoplasms': 0.0163513116815156},
#               {'eligibilityModule_minimumAge': 0.03327062292736635,
#                'eligibilityModule_maximumAge': 0.04325573209173656,
#                'designModule_enrollmentInfo_count': 0.5621213464423505,
#                'PHASE2': 0.014665147787771147,
#                'FdaRegulatedDrug_yes': 0.023146067951008032,
#                'primaryPurpose_TREATMENT': 0.00965733832245688,
#                'masking_NONE': 0.012131295806637233,
#                'healthyVolunteers_no': 0.024666474483039467,
#                'healthyVolunteers_yes': 0.022503823503719777,
#                'duration_of_trial': 0.10340853790968965,
#                'inclusion_count': 0.0395038586585893,
#                'exclusion_count': 0.04282221204641424,
#                'facility_count': 0.051289319753003486,
#                'Neoplasms': 0.017558222316217512}],
#              'no_emb_auc': [0.8641566753213064,
#               0.8694123274458075,
#               0.8625892644961137,
#               0.8722910033705993,
#               0.8660919349909173],
#              'no_emb_precision': [0.741185296324081,
#               0.741218789674143,
#               0.7389631213254944,
#               0.7445440168687402,
#               0.7418154761904762],
#              'no_emb_recall': [0.8660155271725519,
#               0.8772852491860756,
#               0.8656398697721012,
#               0.8842975206611571,
#               0.8739043325820185],
#              'no_emb_accuracy': [0.7818056599048334,
#               0.7854996243425996,
#               0.7799273729025795,
#               0.7904457801152016,
#               0.7848735286751816],
#              'no_emb_f1': [0.7987526707859329,
#               0.8035325151966969,
#               0.7973011937027853,
#               0.8084253906473585,
#               0.8024606186041163],
#              'no_emb_tp': [6916, 7006, 6913, 7062, 6979],
#              'no_emb_tn': [5571, 5540, 5544, 5563, 5557],
#              'no_emb_fp': [2415, 2446, 2442, 2423, 2429],
#              'no_emb_fn': [1070, 980, 1073, 924, 1007],
#              'no_emb_report': [{'0': {'precision': 0.8388796867941575,
#                 'recall': 0.6975957926371149,
#                 'f1-score': 0.7617419840021877,
#                 'support': 7986.0},
#                '1': {'precision': 0.741185296324081,
#                 'recall': 0.8660155271725519,
#                 'f1-score': 0.7987526707859329,
#                 'support': 7986.0},
#                'accuracy': 0.7818056599048334,
#                'macro avg': {'precision': 0.7900324915591193,
#                 'recall': 0.7818056599048334,
#                 'f1-score': 0.7802473273940603,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7900324915591193,
#                 'recall': 0.7818056599048334,
#                 'f1-score': 0.7802473273940603,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8496932515337423,
#                 'recall': 0.6937139994991235,
#                 'f1-score': 0.7638218668137322,
#                 'support': 7986.0},
#                '1': {'precision': 0.741218789674143,
#                 'recall': 0.8772852491860756,
#                 'f1-score': 0.8035325151966969,
#                 'support': 7986.0},
#                'accuracy': 0.7854996243425996,
#                'macro avg': {'precision': 0.7954560206039427,
#                 'recall': 0.7854996243425996,
#                 'f1-score': 0.7836771910052145,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7954560206039427,
#                 'recall': 0.7854996243425996,
#                 'f1-score': 0.7836771910052145,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8378419223212936,
#                 'recall': 0.6942148760330579,
#                 'f1-score': 0.7592960350612887,
#                 'support': 7986.0},
#                '1': {'precision': 0.7389631213254944,
#                 'recall': 0.8656398697721012,
#                 'f1-score': 0.7973011937027853,
#                 'support': 7986.0},
#                'accuracy': 0.7799273729025795,
#                'macro avg': {'precision': 0.788402521823394,
#                 'recall': 0.7799273729025795,
#                 'f1-score': 0.778298614382037,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.788402521823394,
#                 'recall': 0.7799273729025795,
#                 'f1-score': 0.778298614382037,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8575612763989517,
#                 'recall': 0.6965940395692461,
#                 'f1-score': 0.7687417950666758,
#                 'support': 7986.0},
#                '1': {'precision': 0.7445440168687402,
#                 'recall': 0.8842975206611571,
#                 'f1-score': 0.8084253906473585,
#                 'support': 7986.0},
#                'accuracy': 0.7904457801152016,
#                'macro avg': {'precision': 0.8010526466338459,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.7885835928570172,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8010526466338459,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.7885835928570172,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8465874466788543,
#                 'recall': 0.6958427247683446,
#                 'f1-score': 0.7638487972508591,
#                 'support': 7986.0},
#                '1': {'precision': 0.7418154761904762,
#                 'recall': 0.8739043325820185,
#                 'f1-score': 0.8024606186041163,
#                 'support': 7986.0},
#                'accuracy': 0.7848735286751816,
#                'macro avg': {'precision': 0.7942014614346653,
#                 'recall': 0.7848735286751816,
#                 'f1-score': 0.7831547079274876,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7942014614346652,
#                 'recall': 0.7848735286751816,
#                 'f1-score': 0.7831547079274878,
#                 'support': 15972.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.04444847212317863,
#                'designModule_enrollmentInfo_count': 0.5811480312303777,
#                'PHASE2': 0.014106096300136829,
#                'FdaRegulatedDrug_yes': 0.02473933431637326,
#                'healthyVolunteers_no': 0.02441994108775901,
#                'healthyVolunteers_yes': 0.024710433256953674,
#                'duration_of_trial': 0.12193405826683373,
#                'inclusion_count': 0.04334425162150246,
#                'exclusion_count': 0.04680718311334513,
#                'facility_count': 0.055566435536414424,
#                'Neoplasms': 0.018775763147125292},
#               {'eligibilityModule_minimumAge': 0.032435590424891754,
#                'eligibilityModule_maximumAge': 0.04103621745814229,
#                'designModule_enrollmentInfo_count': 0.5602789962658029,
#                'PHASE2': 0.01416904871790621,
#                'oversightHasDmc_yes': 0.011393527610475,
#                'FdaRegulatedDrug_yes': 0.023081847564837617,
#                'FdaRegulatedDevice_no': 0.011547004380257736,
#                'primaryPurpose_TREATMENT': 0.010098218948643439,
#                'healthyVolunteers_no': 0.022464314168165887,
#                'healthyVolunteers_yes': 0.022450346743536978,
#                'duration_of_trial': 0.10216192123475314,
#                'inclusion_count': 0.03965054447850096,
#                'exclusion_count': 0.042049728599605145,
#                'facility_count': 0.049432800138437885,
#                'Neoplasms': 0.01774989326604309},
#               {'eligibilityModule_maximumAge': 0.04477868777255475,
#                'designModule_enrollmentInfo_count': 0.5772818481954142,
#                'PHASE2': 0.014704236657502284,
#                'FdaRegulatedDrug_yes': 0.025688178320319374,
#                'FdaRegulatedDevice_no': 0.011471266783595566,
#                'healthyVolunteers_no': 0.02840592207931992,
#                'healthyVolunteers_yes': 0.021472202609959464,
#                'duration_of_trial': 0.117516383782168,
#                'inclusion_count': 0.04273382027773446,
#                'exclusion_count': 0.04689049918021706,
#                'facility_count': 0.05415246839396357,
#                'Neoplasms': 0.01490448594725135},
#               {'eligibilityModule_minimumAge': 0.03311642803676148,
#                'eligibilityModule_maximumAge': 0.042287294741095785,
#                'designModule_enrollmentInfo_count': 0.5568117699105252,
#                'PHASE2': 0.014301829799908284,
#                'FdaRegulatedDrug_yes': 0.023777043171813592,
#                'FdaRegulatedDevice_no': 0.011629925396355741,
#                'primaryPurpose_TREATMENT': 0.010072734656062565,
#                'masking_NONE': 0.012453278649851868,
#                'healthyVolunteers_no': 0.022506078953177352,
#                'healthyVolunteers_yes': 0.02077427758224579,
#                'duration_of_trial': 0.10378168657634033,
#                'inclusion_count': 0.039736604763412,
#                'exclusion_count': 0.04309837361812875,
#                'facility_count': 0.0493013624628057,
#                'Neoplasms': 0.0163513116815156},
#               {'eligibilityModule_minimumAge': 0.03327062292736635,
#                'eligibilityModule_maximumAge': 0.04325573209173656,
#                'designModule_enrollmentInfo_count': 0.5621213464423505,
#                'PHASE2': 0.014665147787771147,
#                'FdaRegulatedDrug_yes': 0.023146067951008032,
#                'primaryPurpose_TREATMENT': 0.00965733832245688,
#                'masking_NONE': 0.012131295806637233,
#                'healthyVolunteers_no': 0.024666474483039467,
#                'healthyVolunteers_yes': 0.022503823503719777,
#                'duration_of_trial': 0.10340853790968965,
#                'inclusion_count': 0.0395038586585893,
#                'exclusion_count': 0.04282221204641424,
#                'facility_count': 0.051289319753003486,
#                'Neoplasms': 0.017558222316217512}],
#              'with_emb_auc': [0.8804554915755716,
#               0.8832456862118272,
#               0.8767445694001568,
#               0.88562839338991,
#               0.8814699453068664],
#              'with_emb_precision': [0.7540735944750189,
#               0.7557801914184321,
#               0.7487107864202837,
#               0.7563730235559858,
#               0.7536247565462021],
#              'with_emb_recall': [0.8750313047833709,
#               0.8800400701227148,
#               0.8726521412471826,
#               0.8805409466566492,
#               0.8721512647132482],
#              'with_emb_accuracy': [0.7948284497871275,
#               0.7978337089907338,
#               0.7898822940145254,
#               0.7984598046581518,
#               0.7935136488855498],
#              'with_emb_f1': [0.8100620181997333,
#               0.8131906277118889,
#               0.8059442581242049,
#               0.8137476132615865,
#               0.8085674483399118],
#              'with_emb_tp': [6988, 7028, 6969, 7032, 6965],
#              'with_emb_tn': [5707, 5715, 5647, 5721, 5709],
#              'with_emb_fp': [2279, 2271, 2339, 2265, 2277],
#              'with_emb_fn': [998, 958, 1017, 954, 1021],
#              'with_emb_report': [{'0': {'precision': 0.8511558538404176,
#                 'recall': 0.7146255947908841,
#                 'f1-score': 0.7769382615206589,
#                 'support': 7986.0},
#                '1': {'precision': 0.7540735944750189,
#                 'recall': 0.8750313047833709,
#                 'f1-score': 0.8100620181997333,
#                 'support': 7986.0},
#                'accuracy': 0.7948284497871275,
#                'macro avg': {'precision': 0.8026147241577182,
#                 'recall': 0.7948284497871274,
#                 'f1-score': 0.7935001398601962,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8026147241577182,
#                 'recall': 0.7948284497871275,
#                 'f1-score': 0.7935001398601962,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8564363854338378,
#                 'recall': 0.7156273478587528,
#                 'f1-score': 0.7797257657411829,
#                 'support': 7986.0},
#                '1': {'precision': 0.7557801914184321,
#                 'recall': 0.8800400701227148,
#                 'f1-score': 0.8131906277118889,
#                 'support': 7986.0},
#                'accuracy': 0.7978337089907338,
#                'macro avg': {'precision': 0.806108288426135,
#                 'recall': 0.7978337089907338,
#                 'f1-score': 0.7964581967265358,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.806108288426135,
#                 'recall': 0.7978337089907338,
#                 'f1-score': 0.7964581967265358,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8473889555822329,
#                 'recall': 0.7071124467818682,
#                 'f1-score': 0.7709215017064847,
#                 'support': 7986.0},
#                '1': {'precision': 0.7487107864202837,
#                 'recall': 0.8726521412471826,
#                 'f1-score': 0.8059442581242049,
#                 'support': 7986.0},
#                'accuracy': 0.7898822940145254,
#                'macro avg': {'precision': 0.7980498710012582,
#                 'recall': 0.7898822940145254,
#                 'f1-score': 0.7884328799153448,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7980498710012582,
#                 'recall': 0.7898822940145254,
#                 'f1-score': 0.7884328799153447,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8570786516853932,
#                 'recall': 0.7163786626596544,
#                 'f1-score': 0.780437896459996,
#                 'support': 7986.0},
#                '1': {'precision': 0.7563730235559858,
#                 'recall': 0.8805409466566492,
#                 'f1-score': 0.8137476132615865,
#                 'support': 7986.0},
#                'accuracy': 0.7984598046581518,
#                'macro avg': {'precision': 0.8067258376206895,
#                 'recall': 0.7984598046581518,
#                 'f1-score': 0.7970927548607912,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8067258376206895,
#                 'recall': 0.7984598046581518,
#                 'f1-score': 0.7970927548607913,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8482912332838038,
#                 'recall': 0.7148760330578512,
#                 'f1-score': 0.775890187550965,
#                 'support': 7986.0},
#                '1': {'precision': 0.7536247565462021,
#                 'recall': 0.8721512647132482,
#                 'f1-score': 0.8085674483399118,
#                 'support': 7986.0},
#                'accuracy': 0.7935136488855498,
#                'macro avg': {'precision': 0.800957994915003,
#                 'recall': 0.7935136488855496,
#                 'f1-score': 0.7922288179454384,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.800957994915003,
#                 'recall': 0.7935136488855498,
#                 'f1-score': 0.7922288179454384,
#                 'support': 15972.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.8388796867941575,
#                 'recall': 0.6975957926371149,
#                 'f1-score': 0.7617419840021877,
#                 'support': 7986.0},
#                '1': {'precision': 0.741185296324081,
#                 'recall': 0.8660155271725519,
#                 'f1-score': 0.7987526707859329,
#                 'support': 7986.0},
#                'accuracy': 0.7818056599048334,
#                'macro avg': {'precision': 0.7900324915591193,
#                 'recall': 0.7818056599048334,
#                 'f1-score': 0.7802473273940603,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7900324915591193,
#                 'recall': 0.7818056599048334,
#                 'f1-score': 0.7802473273940603,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8496932515337423,
#                 'recall': 0.6937139994991235,
#                 'f1-score': 0.7638218668137322,
#                 'support': 7986.0},
#                '1': {'precision': 0.741218789674143,
#                 'recall': 0.8772852491860756,
#                 'f1-score': 0.8035325151966969,
#                 'support': 7986.0},
#                'accuracy': 0.7854996243425996,
#                'macro avg': {'precision': 0.7954560206039427,
#                 'recall': 0.7854996243425996,
#                 'f1-score': 0.7836771910052145,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7954560206039427,
#                 'recall': 0.7854996243425996,
#                 'f1-score': 0.7836771910052145,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8378419223212936,
#                 'recall': 0.6942148760330579,
#                 'f1-score': 0.7592960350612887,
#                 'support': 7986.0},
#                '1': {'precision': 0.7389631213254944,
#                 'recall': 0.8656398697721012,
#                 'f1-score': 0.7973011937027853,
#                 'support': 7986.0},
#                'accuracy': 0.7799273729025795,
#                'macro avg': {'precision': 0.788402521823394,
#                 'recall': 0.7799273729025795,
#                 'f1-score': 0.778298614382037,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.788402521823394,
#                 'recall': 0.7799273729025795,
#                 'f1-score': 0.778298614382037,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8575612763989517,
#                 'recall': 0.6965940395692461,
#                 'f1-score': 0.7687417950666758,
#                 'support': 7986.0},
#                '1': {'precision': 0.7445440168687402,
#                 'recall': 0.8842975206611571,
#                 'f1-score': 0.8084253906473585,
#                 'support': 7986.0},
#                'accuracy': 0.7904457801152016,
#                'macro avg': {'precision': 0.8010526466338459,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.7885835928570172,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8010526466338459,
#                 'recall': 0.7904457801152016,
#                 'f1-score': 0.7885835928570172,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8465874466788543,
#                 'recall': 0.6958427247683446,
#                 'f1-score': 0.7638487972508591,
#                 'support': 7986.0},
#                '1': {'precision': 0.7418154761904762,
#                 'recall': 0.8739043325820185,
#                 'f1-score': 0.8024606186041163,
#                 'support': 7986.0},
#                'accuracy': 0.7848735286751816,
#                'macro avg': {'precision': 0.7942014614346653,
#                 'recall': 0.7848735286751816,
#                 'f1-score': 0.7831547079274876,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7942014614346652,
#                 'recall': 0.7848735286751816,
#                 'f1-score': 0.7831547079274878,
#                 'support': 15972.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8511558538404176,
#                 'recall': 0.7146255947908841,
#                 'f1-score': 0.7769382615206589,
#                 'support': 7986.0},
#                '1': {'precision': 0.7540735944750189,
#                 'recall': 0.8750313047833709,
#                 'f1-score': 0.8100620181997333,
#                 'support': 7986.0},
#                'accuracy': 0.7948284497871275,
#                'macro avg': {'precision': 0.8026147241577182,
#                 'recall': 0.7948284497871274,
#                 'f1-score': 0.7935001398601962,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8026147241577182,
#                 'recall': 0.7948284497871275,
#                 'f1-score': 0.7935001398601962,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8564363854338378,
#                 'recall': 0.7156273478587528,
#                 'f1-score': 0.7797257657411829,
#                 'support': 7986.0},
#                '1': {'precision': 0.7557801914184321,
#                 'recall': 0.8800400701227148,
#                 'f1-score': 0.8131906277118889,
#                 'support': 7986.0},
#                'accuracy': 0.7978337089907338,
#                'macro avg': {'precision': 0.806108288426135,
#                 'recall': 0.7978337089907338,
#                 'f1-score': 0.7964581967265358,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.806108288426135,
#                 'recall': 0.7978337089907338,
#                 'f1-score': 0.7964581967265358,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8473889555822329,
#                 'recall': 0.7071124467818682,
#                 'f1-score': 0.7709215017064847,
#                 'support': 7986.0},
#                '1': {'precision': 0.7487107864202837,
#                 'recall': 0.8726521412471826,
#                 'f1-score': 0.8059442581242049,
#                 'support': 7986.0},
#                'accuracy': 0.7898822940145254,
#                'macro avg': {'precision': 0.7980498710012582,
#                 'recall': 0.7898822940145254,
#                 'f1-score': 0.7884328799153448,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.7980498710012582,
#                 'recall': 0.7898822940145254,
#                 'f1-score': 0.7884328799153447,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8570786516853932,
#                 'recall': 0.7163786626596544,
#                 'f1-score': 0.780437896459996,
#                 'support': 7986.0},
#                '1': {'precision': 0.7563730235559858,
#                 'recall': 0.8805409466566492,
#                 'f1-score': 0.8137476132615865,
#                 'support': 7986.0},
#                'accuracy': 0.7984598046581518,
#                'macro avg': {'precision': 0.8067258376206895,
#                 'recall': 0.7984598046581518,
#                 'f1-score': 0.7970927548607912,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.8067258376206895,
#                 'recall': 0.7984598046581518,
#                 'f1-score': 0.7970927548607913,
#                 'support': 15972.0}},
#               {'0': {'precision': 0.8482912332838038,
#                 'recall': 0.7148760330578512,
#                 'f1-score': 0.775890187550965,
#                 'support': 7986.0},
#                '1': {'precision': 0.7536247565462021,
#                 'recall': 0.8721512647132482,
#                 'f1-score': 0.8085674483399118,
#                 'support': 7986.0},
#                'accuracy': 0.7935136488855498,
#                'macro avg': {'precision': 0.800957994915003,
#                 'recall': 0.7935136488855496,
#                 'f1-score': 0.7922288179454384,
#                 'support': 15972.0},
#                'weighted avg': {'precision': 0.800957994915003,
#                 'recall': 0.7935136488855498,
#                 'f1-score': 0.7922288179454384,
#                 'support': 15972.0}}]})

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# === CONFIG ===
param_grid_rf = {
    'n_estimators': [500, 600, 700],
    'max_depth': [15, 20, 30],
    'max_features': ['sqrt', 'log2']
}


# === Step 1: Prepare Dataset ===
df_sampled = df.copy()

# === Step 2: PCA on cls_embedding ===
embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

pca = PCA()
pca.fit(embeddings_matrix)
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
print(f"Optimal PCA components: {optimal_components}")

pca = PCA(n_components=optimal_components)
reduced_embeddings = pca.fit_transform(embeddings_matrix)
reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
df_pca.index = df_sampled.index

# === Step 3: Feature Processing ===
df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
X = df_sampled.drop(columns=['status_binary'])
y = df_sampled['status_binary']

# Identify feature types
numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
dummy_features = [col for col in X.columns if col not in numerical_features]

# Convert boolean to int
for col in dummy_features:
    if X[col].dtype == 'bool':
        X[col] = X[col].astype(int)

# Create X_emb
X_emb = pd.concat([X, df_pca], axis=1)

# Standardize tabular and embedding features
scaler = StandardScaler()
X[numerical_features] = scaler.fit_transform(X[numerical_features])
X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

# === Step 4: Feature Selection ===
def apply_feature_selection(X_train, y_train, X_test):
    selector_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
    selector_model.fit(X_train, y_train)
    selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

    selected_mask = selector.get_support()
    selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

    return selector.transform(X_train), selector.transform(X_test), selected_feature_names

X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
    clf = RandomForestClassifier(random_state=42, class_weight='balanced')
    grid = GridSearchCV(clf, param_grid_rf, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)

    grid.fit(X_train, y_train)
    best_model = grid.best_estimator_
    print(f"Best parameters for this run: {grid.best_params_}")
    y_pred = best_model.predict(X_test)
    y_prob = best_model.predict_proba(X_test)[:, 1]

    auc = roc_auc_score(y_test, y_prob)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

    # <-- Add classification report here
    report = classification_report(y_test, y_pred, output_dict=True)

    result = {
        'auc': auc,
        'precision': precision,
        'recall': recall,
        'accuracy': accuracy,
        'f1': f1,
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'report': report  
    }

    if return_importance and feature_names is not None:
        importances = best_model.feature_importances_
        feature_importance_dict = dict(zip(feature_names, importances))
        result['feature_importance'] = feature_importance_dict

    return result

# === Train and Evaluate ===
# Pass selected feature names after feature selection
metrics_no_emb = train_and_eval_all(
    X_train_sel, y_train, X_test_sel, y_test,
    feature_names=selected_feature_names,
    return_importance=True
)

metrics_with_emb = train_and_eval_all(
    X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

# Save metrics to results
for metric, value in metrics_no_emb.items():
    results[f'no_emb_{metric}'].append(value)
for metric, value in metrics_with_emb.items():
    results[f'with_emb_{metric}'].append(value)

results['no_emb_reports'].append(metrics_no_emb['report'])
results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===
print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best parameters for this run: {'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 500}
#
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.6244
# duration_of_trial: 0.1260
# facility_count: 0.0561
# eligibilityModule_maximumAge: 0.0443
# inclusion_count: 0.0430
# healthyVolunteers_no: 0.0267
# FdaRegulatedDrug_yes: 0.0247
# healthyVolunteers_yes: 0.0231
# Neoplasms: 0.0176
# PHASE2: 0.0142
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.60 ± 0.00  0.64 ± 0.00  0.62 ± 0.00   7986.00 ± 0.00
# 1     1  0.93 ± 0.00  0.92 ± 0.00  0.93 ± 0.00  44704.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.88 ± 0.00  0.48 ± 0.00  0.62 ± 0.00   7986.00 ± 0.00
# 1     1  0.91 ± 0.00  0.99 ± 0.00  0.95 ± 0.00  44704.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.044312408775606986,
#                'designModule_enrollmentInfo_count': 0.6243626441527197,
#                'PHASE2': 0.014203183683319529,
#                'FdaRegulatedDrug_yes': 0.02466501620625897,
#                'healthyVolunteers_no': 0.026723906140434548,
#                'healthyVolunteers_yes': 0.023057492839890985,
#                'duration_of_trial': 0.1259837211513363,
#                'inclusion_count': 0.043027971588192195,
#                'facility_count': 0.0560538540388548,
#                'Neoplasms': 0.017609801423386254}],
#              'no_emb_auc': [0.8657674768196706],
#              'no_emb_precision': [0.9343924683730509],
#              'no_emb_recall': [0.9235862562634216],
#              'no_emb_accuracy': [0.8801480356803948],
#              'no_emb_f1': [0.9289579372489903],
#              'no_emb_tp': [41288],
#              'no_emb_tn': [5087],
#              'no_emb_fp': [2899],
#              'no_emb_fn': [3416],
#              'no_emb_report': [{'0': {'precision': 0.5982594378454663,
#                 'recall': 0.6369897320310544,
#                 'f1-score': 0.6170174055430894,
#                 'support': 7986.0},
#                '1': {'precision': 0.9343924683730509,
#                 'recall': 0.9235862562634216,
#                 'f1-score': 0.9289579372489903,
#                 'support': 44704.0},
#                'accuracy': 0.8801480356803948,
#                'macro avg': {'precision': 0.7663259531092586,
#                 'recall': 0.780287994147238,
#                 'f1-score': 0.7729876713960399,
#                 'support': 52690.0},
#                'weighted avg': {'precision': 0.8834462094663648,
#                 'recall': 0.8801480356803948,
#                 'f1-score': 0.8816784328609979,
#                 'support': 52690.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.044312408775606986,
#                'designModule_enrollmentInfo_count': 0.6243626441527197,
#                'PHASE2': 0.014203183683319529,
#                'FdaRegulatedDrug_yes': 0.02466501620625897,
#                'healthyVolunteers_no': 0.026723906140434548,
#                'healthyVolunteers_yes': 0.023057492839890985,
#                'duration_of_trial': 0.1259837211513363,
#                'inclusion_count': 0.043027971588192195,
#                'facility_count': 0.0560538540388548,
#                'Neoplasms': 0.017609801423386254}],
#              'with_emb_auc': [0.8885914537650087],
#              'with_emb_precision': [0.9144335230212105],
#              'with_emb_recall': [0.9885021474588404],
#              'with_emb_accuracy': [0.9117669386980451],
#              'with_emb_f1': [0.9500263358737598],
#              'with_emb_tp': [44190],
#              'with_emb_tn': [3851],
#              'with_emb_fp': [4135],
#              'with_emb_fn': [514],
#              'with_emb_report': [{'0': {'precision': 0.8822451317296678,
#                 'recall': 0.48221888304532934,
#                 'f1-score': 0.6235932313173023,
#                 'support': 7986.0},
#                '1': {'precision': 0.9144335230212105,
#                 'recall': 0.9885021474588404,
#                 'f1-score': 0.9500263358737598,
#                 'support': 44704.0},
#                'accuracy': 0.9117669386980451,
#                'macro avg': {'precision': 0.8983393273754392,
#                 'recall': 0.7353605152520848,
#                 'f1-score': 0.786809783595531,
#                 'support': 52690.0},
#                'weighted avg': {'precision': 0.9095548649674193,
#                 'recall': 0.9117669386980451,
#                 'f1-score': 0.9005502536382717,
#                 'support': 52690.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.5982594378454663,
#                 'recall': 0.6369897320310544,
#                 'f1-score': 0.6170174055430894,
#                 'support': 7986.0},
#                '1': {'precision': 0.9343924683730509,
#                 'recall': 0.9235862562634216,
#                 'f1-score': 0.9289579372489903,
#                 'support': 44704.0},
#                'accuracy': 0.8801480356803948,
#                'macro avg': {'precision': 0.7663259531092586,
#                 'recall': 0.780287994147238,
#                 'f1-score': 0.7729876713960399,
#                 'support': 52690.0},
#                'weighted avg': {'precision': 0.8834462094663648,
#                 'recall': 0.8801480356803948,
#                 'f1-score': 0.8816784328609979,
#                 'support': 52690.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8822451317296678,
#                 'recall': 0.48221888304532934,
#                 'f1-score': 0.6235932313173023,
#                 'support': 7986.0},
#                '1': {'precision': 0.9144335230212105,
#                 'recall': 0.9885021474588404,
#                 'f1-score': 0.9500263358737598,
#                 'support': 44704.0},
#                'accuracy': 0.9117669386980451,
#                'macro avg': {'precision': 0.8983393273754392,
#                 'recall': 0.7353605152520848,
#                 'f1-score': 0.786809783595531,
#                 'support': 52690.0},
#                'weighted avg': {'precision': 0.9095548649674193,
#                 'recall': 0.9117669386980451,
#                 'f1-score': 0.9005502536382717,
#                 'support': 52690.0}}]})

# %%
#Random forest (downsample + rebalance)

# === CONFIG ===
n_runs = 5
desired_ratio = 2
param_grid_rf = {
    'n_estimators': [400, 500, 600],
    'max_depth': [15, 20, 30],
    # 'max_features': ['sqrt', 'log2']
}

# === RESULTS STORAGE ===
results = defaultdict(list)

# === LOOP ===
for run in range(n_runs):
    print(f"\n===================== Run {run+1}/{n_runs} =====================")

    # === Step 1: Prepare Dataset ===
    df_run = df.copy()
    # Undersample majority class
    df_minority = df_run[df_run['status_binary'] == 0]
    df_majority = df_run[df_run['status_binary'] == 1].sample(
        n=int(desired_ratio * len(df_minority)), random_state=run
    )
    df_sampled = pd.concat([df_majority, df_minority]).sample(frac=1, random_state=run).reset_index(drop=True)

    # === Step 2: PCA on cls_embedding ===
    embeddings_matrix = np.vstack(df_sampled['cls_embedding'].values)
    embeddings_matrix = StandardScaler().fit_transform(embeddings_matrix)  # Normalize before PCA

    pca = PCA()
    pca.fit(embeddings_matrix)
    cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
    optimal_components = np.argmax(cumulative_variance >= 0.95) + 1
    print(f"Optimal PCA components: {optimal_components}")

    pca = PCA(n_components=optimal_components)
    reduced_embeddings = pca.fit_transform(embeddings_matrix)
    reduced_embeddings = StandardScaler().fit_transform(reduced_embeddings)

    df_pca = pd.DataFrame(reduced_embeddings, columns=[f'pca_emb_{i}' for i in range(optimal_components)])
    df_pca.index = df_sampled.index

    # === Step 3: Feature Processing ===
    df_sampled = df_sampled.drop(columns=['cls_embedding'])  # Drop embedding
    X = df_sampled.drop(columns=['status_binary'])
    y = df_sampled['status_binary']

    # Identify feature types
    numerical_features = [col for col in X.columns if X[col].dtype in [np.float64, np.int64]]
    dummy_features = [col for col in X.columns if col not in numerical_features]

    # Convert boolean to int
    for col in dummy_features:
        if X[col].dtype == 'bool':
            X[col] = X[col].astype(int)

    # Create X_emb
    X_emb = pd.concat([X, df_pca], axis=1)

    # Standardize tabular and embedding features
    scaler = StandardScaler()
    X[numerical_features] = scaler.fit_transform(X[numerical_features])
    X_emb[numerical_features] = scaler.transform(X_emb[numerical_features])
    X_emb[df_pca.columns] = scaler.fit_transform(X_emb[df_pca.columns])

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
    X_train_emb, X_test_emb, y_train_emb, y_test_emb = train_test_split(X_emb, y, stratify=y, test_size=0.2, random_state=42)

    # === Step 4: Feature Selection ===
    def apply_feature_selection(X_train, y_train, X_test):
        selector_model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
        selector_model.fit(X_train, y_train)
        selector = SelectFromModel(selector_model, threshold='mean', prefit=True)

        selected_mask = selector.get_support()
        selected_feature_names = X_train.columns[selected_mask]  # <-- get the names

        return selector.transform(X_train), selector.transform(X_test), selected_feature_names

    X_train_sel, X_test_sel, selected_feature_names = apply_feature_selection(X_train, y_train, X_test)
    X_train_emb_sel, X_test_emb_sel, selected_feature_names_emb = apply_feature_selection(X_train_emb, y_train_emb, X_test_emb)

    def train_and_eval_all(X_train, y_train, X_test, y_test, feature_names=None, return_importance=False):
        clf = RandomForestClassifier(random_state=42, class_weight='balanced')
        grid = GridSearchCV(clf, param_grid_rf, cv=3, scoring='roc_auc', n_jobs=-1, verbose=0)

        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        print(f"Best parameters for this run: {grid.best_params_}")
        y_pred = best_model.predict(X_test)
        y_prob = best_model.predict_proba(X_test)[:, 1]

        auc = roc_auc_score(y_test, y_prob)
        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

        # <-- Add classification report here
        report = classification_report(y_test, y_pred, output_dict=True)

        result = {
            'auc': auc,
            'precision': precision,
            'recall': recall,
            'accuracy': accuracy,
            'f1': f1,
            'tp': tp,
            'tn': tn,
            'fp': fp,
            'fn': fn,
            'report': report  
        }

        if return_importance and feature_names is not None:
            importances = best_model.feature_importances_
            feature_importance_dict = dict(zip(feature_names, importances))
            result['feature_importance'] = feature_importance_dict

        return result

    # === Train and Evaluate ===
    # Pass selected feature names after feature selection
    metrics_no_emb = train_and_eval_all(
        X_train_sel, y_train, X_test_sel, y_test,
        feature_names=selected_feature_names,
        return_importance=True
    )

    metrics_with_emb = train_and_eval_all(
        X_train_emb_sel, y_train_emb, X_test_emb_sel, y_test_emb) # Don't return importance for embeddings
    results['no_emb_feature_importances'].append(metrics_no_emb['feature_importance'])

    # Save metrics to results
    for metric, value in metrics_no_emb.items():
        results[f'no_emb_{metric}'].append(value)
    for metric, value in metrics_with_emb.items():
        results[f'with_emb_{metric}'].append(value)
    
    results['no_emb_reports'].append(metrics_no_emb['report'])
    results['with_emb_reports'].append(metrics_with_emb['report'])


# Aggregate feature importances
importance_accumulator = defaultdict(list)

for run_dict in results['no_emb_feature_importances']:
    for feature, importance in run_dict.items():
        importance_accumulator[feature].append(importance)

# Compute mean importance for each feature
mean_importances = {feat: np.mean(imps) for feat, imps in importance_accumulator.items()}

# Sort and display top features
top_features = sorted(mean_importances.items(), key=lambda x: x[1], reverse=True)

print("\n===================== Top Features Without Embeddings =====================")
for feat, importance in top_features[:20]:  # Change 20 to whatever top-k you want
    print(f"{feat}: {importance:.4f}")

# === Step 5: Report Mean ± Std for all metrics ===
def aggregate_classification_reports_pretty(report_list, label_names=['0', '1']):
    metrics = ['precision', 'recall', 'f1-score', 'support']
    df_rows = []

    for label in label_names:
        row = {'class': label}
        for metric in metrics:
            values = [r[label][metric] for r in report_list]
            row[metric] = f"{np.mean(values):.2f} ± {np.std(values):.2f}"
        df_rows.append(row)
    
    return pd.DataFrame(df_rows)

# === After your loop ===

print("\n===== Aggregated Classification Report (No Embeddings) =====")
print(aggregate_classification_reports_pretty(results['no_emb_reports']))

print("\n===== Aggregated Classification Report (With Embeddings) =====")
print(aggregate_classification_reports_pretty(results['with_emb_reports']))
# Out:
# ===================== Run 1/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'n_estimators': 600}
# Best parameters for this run: {'max_depth': 30, 'n_estimators': 600}
#
# ===================== Run 2/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'n_estimators': 600}
# Best parameters for this run: {'max_depth': 30, 'n_estimators': 600}
#
# ===================== Run 3/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'n_estimators': 600}
# Best parameters for this run: {'max_depth': 30, 'n_estimators': 600}
#
# ===================== Run 4/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'n_estimators': 600}
# Best parameters for this run: {'max_depth': 30, 'n_estimators': 600}
#
# ===================== Run 5/5 =====================
# Optimal PCA components: 318
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /Users/lijiazheng/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Best parameters for this run: {'max_depth': 15, 'n_estimators': 600}
# Best parameters for this run: {'max_depth': 30, 'n_estimators': 600}
#
# ===================== Top Features Without Embeddings =====================
# designModule_enrollmentInfo_count: 0.6074
# duration_of_trial: 0.1325
# facility_count: 0.0586
# inclusion_count: 0.0468
# eligibilityModule_maximumAge: 0.0468
# healthyVolunteers_no: 0.0267
# FdaRegulatedDrug_yes: 0.0242
# healthyVolunteers_yes: 0.0228
# Neoplasms: 0.0179
# PHASE2: 0.0138
# oversightHasDmc_yes: 0.0121
#
# ===== Aggregated Classification Report (No Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.77 ± 0.00  0.66 ± 0.00  0.71 ± 0.00   7986.00 ± 0.00
# 1     1  0.84 ± 0.00  0.90 ± 0.00  0.87 ± 0.00  15972.00 ± 0.00
#
# ===== Aggregated Classification Report (With Embeddings) =====
#   class    precision       recall     f1-score          support
# 0     0  0.88 ± 0.00  0.58 ± 0.00  0.70 ± 0.00   7986.00 ± 0.00
# 1     1  0.82 ± 0.00  0.96 ± 0.00  0.88 ± 0.00  15972.00 ± 0.00

# %%
results
# Out:
# defaultdict(list,
#             {'no_emb_feature_importances': [{'eligibilityModule_maximumAge': 0.047597994357433226,
#                'designModule_enrollmentInfo_count': 0.6061301344437807,
#                'PHASE2': 0.013122923113864619,
#                'FdaRegulatedDrug_yes': 0.025247168570931216,
#                'healthyVolunteers_no': 0.027648622242689703,
#                'healthyVolunteers_yes': 0.024547925482909155,
#                'duration_of_trial': 0.13303815646778658,
#                'inclusion_count': 0.04678112918807913,
#                'facility_count': 0.05907143473095601,
#                'Neoplasms': 0.01681451140156965},
#               {'eligibilityModule_maximumAge': 0.046127021985294024,
#                'designModule_enrollmentInfo_count': 0.6118873913392691,
#                'PHASE2': 0.013407665228130687,
#                'FdaRegulatedDrug_yes': 0.02514066196492969,
#                'healthyVolunteers_no': 0.026507564237411085,
#                'healthyVolunteers_yes': 0.02207990264034848,
#                'duration_of_trial': 0.13171646150047114,
#                'inclusion_count': 0.0466618059493423,
#                'facility_count': 0.059003051007799706,
#                'Neoplasms': 0.01746847414700368},
#               {'eligibilityModule_maximumAge': 0.04772583934876962,
#                'designModule_enrollmentInfo_count': 0.6105281682857426,
#                'PHASE2': 0.012971112136657127,
#                'FdaRegulatedDrug_yes': 0.02441409922441306,
#                'healthyVolunteers_no': 0.02685768124460041,
#                'healthyVolunteers_yes': 0.02349459743062239,
#                'duration_of_trial': 0.13320541624323987,
#                'inclusion_count': 0.04634305872892231,
#                'facility_count': 0.05749578421143122,
#                'Neoplasms': 0.016964243145601195},
#               {'eligibilityModule_maximumAge': 0.046198038471944765,
#                'designModule_enrollmentInfo_count': 0.6097626191482161,
#                'PHASE2': 0.013720550981932545,
#                'FdaRegulatedDrug_yes': 0.024023868653213157,
#                'healthyVolunteers_no': 0.02590424093671442,
#                'healthyVolunteers_yes': 0.022602710292599273,
#                'duration_of_trial': 0.13343918414210068,
#                'inclusion_count': 0.04709846384118507,
#                'facility_count': 0.05888250597554528,
#                'Neoplasms': 0.018367817556548843},
#               {'eligibilityModule_maximumAge': 0.04621794016189325,
#                'designModule_enrollmentInfo_count': 0.5986903398801051,
#                'PHASE2': 0.015930543722942093,
#                'oversightHasDmc_yes': 0.012090704963615844,
#                'FdaRegulatedDrug_yes': 0.022268380894465395,
#                'healthyVolunteers_no': 0.026758226530961063,
#                'healthyVolunteers_yes': 0.021096163682576163,
#                'duration_of_trial': 0.13096301400443644,
#                'inclusion_count': 0.04724461417558055,
#                'facility_count': 0.058699570640625094,
#                'Neoplasms': 0.020040501342798934}],
#              'no_emb_auc': [0.8626177155501717,
#               0.8653559589850732,
#               0.86313989313505,
#               0.8652762780019052,
#               0.8630876244171101],
#              'no_emb_precision': [0.8445383081074739,
#               0.8411225859151642,
#               0.8419879129261281,
#               0.8405079513019165,
#               0.8416281653897889],
#              'no_emb_recall': [0.9013273228149261,
#               0.9025795141497621,
#               0.8984472827448035,
#               0.9033934385174055,
#               0.9010142749812171],
#              'no_emb_accuracy': [0.8236079806327741,
#               0.8213957759412305,
#               0.8198931463394273,
#               0.8213122965189081,
#               0.8209783788296185],
#              'no_emb_f1': [0.8720092070991581,
#               0.8707680227114856,
#               0.8693018325003786,
#               0.8708168623072513,
#               0.8703093344622177],
#              'no_emb_tp': [14396, 14416, 14350, 14429, 14391],
#              'no_emb_tn': [5336, 5263, 5293, 5248, 5278],
#              'no_emb_fp': [2650, 2723, 2693, 2738, 2708],
#              'no_emb_fn': [1576, 1556, 1622, 1543, 1581],
#              'no_emb_report': [{'0': {'precision': 0.7719907407407407,
#                 'recall': 0.6681692962684698,
#                 'f1-score': 0.7163377634581823,
#                 'support': 7986.0},
#                '1': {'precision': 0.8445383081074739,
#                 'recall': 0.9013273228149261,
#                 'f1-score': 0.8720092070991581,
#                 'support': 15972.0},
#                'accuracy': 0.8236079806327741,
#                'macro avg': {'precision': 0.8082645244241073,
#                 'recall': 0.7847483095416979,
#                 'f1-score': 0.7941734852786702,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8203557856518963,
#                 'recall': 0.8236079806327741,
#                 'f1-score': 0.8201187258854995,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.771814048980789,
#                 'recall': 0.6590282995241673,
#                 'f1-score': 0.7109760216143195,
#                 'support': 7986.0},
#                '1': {'precision': 0.8411225859151642,
#                 'recall': 0.9025795141497621,
#                 'f1-score': 0.8707680227114856,
#                 'support': 15972.0},
#                'accuracy': 0.8213957759412305,
#                'macro avg': {'precision': 0.8064683174479765,
#                 'recall': 0.7808039068369648,
#                 'f1-score': 0.7908720221629025,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8180197402703724,
#                 'recall': 0.8213957759412305,
#                 'f1-score': 0.8175040223457635,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7654374548083875,
#                 'recall': 0.6627848735286752,
#                 'f1-score': 0.710422119320851,
#                 'support': 7986.0},
#                '1': {'precision': 0.8419879129261281,
#                 'recall': 0.8984472827448035,
#                 'f1-score': 0.8693018325003786,
#                 'support': 15972.0},
#                'accuracy': 0.8198931463394273,
#                'macro avg': {'precision': 0.8037126838672578,
#                 'recall': 0.7806160781367393,
#                 'f1-score': 0.7898619759106148,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.816471093553548,
#                 'recall': 0.8198931463394273,
#                 'f1-score': 0.8163419281072027,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7727875128847004,
#                 'recall': 0.6571500125219133,
#                 'f1-score': 0.710293022941057,
#                 'support': 7986.0},
#                '1': {'precision': 0.8405079513019165,
#                 'recall': 0.9033934385174055,
#                 'f1-score': 0.8708168623072513,
#                 'support': 15972.0},
#                'accuracy': 0.8213122965189081,
#                'macro avg': {'precision': 0.8066477320933084,
#                 'recall': 0.7802717255196594,
#                 'f1-score': 0.7905549426241542,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8179344718295111,
#                 'recall': 0.8213122965189081,
#                 'f1-score': 0.8173089158518532,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7694999271030762,
#                 'recall': 0.6609065865264212,
#                 'f1-score': 0.7110811721118222,
#                 'support': 7986.0},
#                '1': {'precision': 0.8416281653897889,
#                 'recall': 0.9010142749812171,
#                 'f1-score': 0.8703093344622177,
#                 'support': 15972.0},
#                'accuracy': 0.8209783788296185,
#                'macro avg': {'precision': 0.8055640462464326,
#                 'recall': 0.7809604307538192,
#                 'f1-score': 0.79069525328702,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.817585419294218,
#                 'recall': 0.8209783788296185,
#                 'f1-score': 0.8172332803454192,
#                 'support': 23958.0}}],
#              'no_emb_feature_importance': [{'eligibilityModule_maximumAge': 0.047597994357433226,
#                'designModule_enrollmentInfo_count': 0.6061301344437807,
#                'PHASE2': 0.013122923113864619,
#                'FdaRegulatedDrug_yes': 0.025247168570931216,
#                'healthyVolunteers_no': 0.027648622242689703,
#                'healthyVolunteers_yes': 0.024547925482909155,
#                'duration_of_trial': 0.13303815646778658,
#                'inclusion_count': 0.04678112918807913,
#                'facility_count': 0.05907143473095601,
#                'Neoplasms': 0.01681451140156965},
#               {'eligibilityModule_maximumAge': 0.046127021985294024,
#                'designModule_enrollmentInfo_count': 0.6118873913392691,
#                'PHASE2': 0.013407665228130687,
#                'FdaRegulatedDrug_yes': 0.02514066196492969,
#                'healthyVolunteers_no': 0.026507564237411085,
#                'healthyVolunteers_yes': 0.02207990264034848,
#                'duration_of_trial': 0.13171646150047114,
#                'inclusion_count': 0.0466618059493423,
#                'facility_count': 0.059003051007799706,
#                'Neoplasms': 0.01746847414700368},
#               {'eligibilityModule_maximumAge': 0.04772583934876962,
#                'designModule_enrollmentInfo_count': 0.6105281682857426,
#                'PHASE2': 0.012971112136657127,
#                'FdaRegulatedDrug_yes': 0.02441409922441306,
#                'healthyVolunteers_no': 0.02685768124460041,
#                'healthyVolunteers_yes': 0.02349459743062239,
#                'duration_of_trial': 0.13320541624323987,
#                'inclusion_count': 0.04634305872892231,
#                'facility_count': 0.05749578421143122,
#                'Neoplasms': 0.016964243145601195},
#               {'eligibilityModule_maximumAge': 0.046198038471944765,
#                'designModule_enrollmentInfo_count': 0.6097626191482161,
#                'PHASE2': 0.013720550981932545,
#                'FdaRegulatedDrug_yes': 0.024023868653213157,
#                'healthyVolunteers_no': 0.02590424093671442,
#                'healthyVolunteers_yes': 0.022602710292599273,
#                'duration_of_trial': 0.13343918414210068,
#                'inclusion_count': 0.04709846384118507,
#                'facility_count': 0.05888250597554528,
#                'Neoplasms': 0.018367817556548843},
#               {'eligibilityModule_maximumAge': 0.04621794016189325,
#                'designModule_enrollmentInfo_count': 0.5986903398801051,
#                'PHASE2': 0.015930543722942093,
#                'oversightHasDmc_yes': 0.012090704963615844,
#                'FdaRegulatedDrug_yes': 0.022268380894465395,
#                'healthyVolunteers_no': 0.026758226530961063,
#                'healthyVolunteers_yes': 0.021096163682576163,
#                'duration_of_trial': 0.13096301400443644,
#                'inclusion_count': 0.04724461417558055,
#                'facility_count': 0.058699570640625094,
#                'Neoplasms': 0.020040501342798934}],
#              'with_emb_auc': [0.8835402357644535,
#               0.8850219367113084,
#               0.8819786068770864,
#               0.8832549412323055,
#               0.8806778786241815],
#              'with_emb_precision': [0.820979395236821,
#               0.8195766064364375,
#               0.8177025083879214,
#               0.8194681759931653,
#               0.818600417625957],
#              'with_emb_recall': [0.9604307538191835,
#               0.9598672677185074,
#               0.9613072877535688,
#               0.9608690207863761,
#               0.9572376659153519],
#              'with_emb_accuracy': [0.8340011687119125,
#               0.8323733199766258,
#               0.8313298271975957,
#               0.8327907170882377,
#               0.8300776358627598],
#              'with_emb_f1': [0.8852468476786797,
#               0.8841917065574716,
#               0.8837088837088837,
#               0.8845533141210374,
#               0.8825074316719097],
#              'with_emb_tp': [15340, 15331, 15354, 15347, 15289],
#              'with_emb_tn': [4641, 4611, 4563, 4605, 4598],
#              'with_emb_fp': [3345, 3375, 3423, 3381, 3388],
#              'with_emb_fn': [632, 641, 618, 625, 683],
#              'with_emb_report': [{'0': {'precision': 0.8801441304760098,
#                 'recall': 0.5811419984973704,
#                 'f1-score': 0.7000527943283807,
#                 'support': 7986.0},
#                '1': {'precision': 0.820979395236821,
#                 'recall': 0.9604307538191835,
#                 'f1-score': 0.8852468476786797,
#                 'support': 15972.0},
#                'accuracy': 0.8340011687119125,
#                'macro avg': {'precision': 0.8505617628564154,
#                 'recall': 0.7707863761582769,
#                 'f1-score': 0.7926498210035302,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8407009736498839,
#                 'recall': 0.8340011687119125,
#                 'f1-score': 0.8235154965619133,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.877951256664128,
#                 'recall': 0.5773854244928626,
#                 'f1-score': 0.6966309110137483,
#                 'support': 7986.0},
#                '1': {'precision': 0.8195766064364375,
#                 'recall': 0.9598672677185074,
#                 'f1-score': 0.8841917065574716,
#                 'support': 15972.0},
#                'accuracy': 0.8323733199766258,
#                'macro avg': {'precision': 0.8487639315502827,
#                 'recall': 0.768626346105685,
#                 'f1-score': 0.79041130878561,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8390348231790009,
#                 'recall': 0.8323733199766258,
#                 'f1-score': 0.8216714413762306,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8807180081065431,
#                 'recall': 0.5713749060856499,
#                 'f1-score': 0.6930963773069037,
#                 'support': 7986.0},
#                '1': {'precision': 0.8177025083879214,
#                 'recall': 0.9613072877535688,
#                 'f1-score': 0.8837088837088837,
#                 'support': 15972.0},
#                'accuracy': 0.8313298271975957,
#                'macro avg': {'precision': 0.8492102582472323,
#                 'recall': 0.7663410969196094,
#                 'f1-score': 0.7884026305078937,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8387076749607952,
#                 'recall': 0.8313298271975957,
#                 'f1-score': 0.8201713815748902,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8804971319311663,
#                 'recall': 0.5766341096919609,
#                 'f1-score': 0.6968825665859564,
#                 'support': 7986.0},
#                '1': {'precision': 0.8194681759931653,
#                 'recall': 0.9608690207863761,
#                 'f1-score': 0.8845533141210374,
#                 'support': 15972.0},
#                'accuracy': 0.8327907170882377,
#                'macro avg': {'precision': 0.8499826539621658,
#                 'recall': 0.7687515652391685,
#                 'f1-score': 0.790717940353497,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8398111613058324,
#                 'recall': 0.8327907170882377,
#                 'f1-score': 0.8219963982760103,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8706684340087105,
#                 'recall': 0.5757575757575758,
#                 'f1-score': 0.6931484133564483,
#                 'support': 7986.0},
#                '1': {'precision': 0.818600417625957,
#                 'recall': 0.9572376659153519,
#                 'f1-score': 0.8825074316719097,
#                 'support': 15972.0},
#                'accuracy': 0.8300776358627598,
#                'macro avg': {'precision': 0.8446344258173337,
#                 'recall': 0.7664976208364638,
#                 'f1-score': 0.787827922514179,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8359564230868748,
#                 'recall': 0.8300776358627598,
#                 'f1-score': 0.8193877589000893,
#                 'support': 23958.0}}],
#              'no_emb_reports': [{'0': {'precision': 0.7719907407407407,
#                 'recall': 0.6681692962684698,
#                 'f1-score': 0.7163377634581823,
#                 'support': 7986.0},
#                '1': {'precision': 0.8445383081074739,
#                 'recall': 0.9013273228149261,
#                 'f1-score': 0.8720092070991581,
#                 'support': 15972.0},
#                'accuracy': 0.8236079806327741,
#                'macro avg': {'precision': 0.8082645244241073,
#                 'recall': 0.7847483095416979,
#                 'f1-score': 0.7941734852786702,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8203557856518963,
#                 'recall': 0.8236079806327741,
#                 'f1-score': 0.8201187258854995,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.771814048980789,
#                 'recall': 0.6590282995241673,
#                 'f1-score': 0.7109760216143195,
#                 'support': 7986.0},
#                '1': {'precision': 0.8411225859151642,
#                 'recall': 0.9025795141497621,
#                 'f1-score': 0.8707680227114856,
#                 'support': 15972.0},
#                'accuracy': 0.8213957759412305,
#                'macro avg': {'precision': 0.8064683174479765,
#                 'recall': 0.7808039068369648,
#                 'f1-score': 0.7908720221629025,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8180197402703724,
#                 'recall': 0.8213957759412305,
#                 'f1-score': 0.8175040223457635,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7654374548083875,
#                 'recall': 0.6627848735286752,
#                 'f1-score': 0.710422119320851,
#                 'support': 7986.0},
#                '1': {'precision': 0.8419879129261281,
#                 'recall': 0.8984472827448035,
#                 'f1-score': 0.8693018325003786,
#                 'support': 15972.0},
#                'accuracy': 0.8198931463394273,
#                'macro avg': {'precision': 0.8037126838672578,
#                 'recall': 0.7806160781367393,
#                 'f1-score': 0.7898619759106148,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.816471093553548,
#                 'recall': 0.8198931463394273,
#                 'f1-score': 0.8163419281072027,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7727875128847004,
#                 'recall': 0.6571500125219133,
#                 'f1-score': 0.710293022941057,
#                 'support': 7986.0},
#                '1': {'precision': 0.8405079513019165,
#                 'recall': 0.9033934385174055,
#                 'f1-score': 0.8708168623072513,
#                 'support': 15972.0},
#                'accuracy': 0.8213122965189081,
#                'macro avg': {'precision': 0.8066477320933084,
#                 'recall': 0.7802717255196594,
#                 'f1-score': 0.7905549426241542,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8179344718295111,
#                 'recall': 0.8213122965189081,
#                 'f1-score': 0.8173089158518532,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.7694999271030762,
#                 'recall': 0.6609065865264212,
#                 'f1-score': 0.7110811721118222,
#                 'support': 7986.0},
#                '1': {'precision': 0.8416281653897889,
#                 'recall': 0.9010142749812171,
#                 'f1-score': 0.8703093344622177,
#                 'support': 15972.0},
#                'accuracy': 0.8209783788296185,
#                'macro avg': {'precision': 0.8055640462464326,
#                 'recall': 0.7809604307538192,
#                 'f1-score': 0.79069525328702,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.817585419294218,
#                 'recall': 0.8209783788296185,
#                 'f1-score': 0.8172332803454192,
#                 'support': 23958.0}}],
#              'with_emb_reports': [{'0': {'precision': 0.8801441304760098,
#                 'recall': 0.5811419984973704,
#                 'f1-score': 0.7000527943283807,
#                 'support': 7986.0},
#                '1': {'precision': 0.820979395236821,
#                 'recall': 0.9604307538191835,
#                 'f1-score': 0.8852468476786797,
#                 'support': 15972.0},
#                'accuracy': 0.8340011687119125,
#                'macro avg': {'precision': 0.8505617628564154,
#                 'recall': 0.7707863761582769,
#                 'f1-score': 0.7926498210035302,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8407009736498839,
#                 'recall': 0.8340011687119125,
#                 'f1-score': 0.8235154965619133,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.877951256664128,
#                 'recall': 0.5773854244928626,
#                 'f1-score': 0.6966309110137483,
#                 'support': 7986.0},
#                '1': {'precision': 0.8195766064364375,
#                 'recall': 0.9598672677185074,
#                 'f1-score': 0.8841917065574716,
#                 'support': 15972.0},
#                'accuracy': 0.8323733199766258,
#                'macro avg': {'precision': 0.8487639315502827,
#                 'recall': 0.768626346105685,
#                 'f1-score': 0.79041130878561,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8390348231790009,
#                 'recall': 0.8323733199766258,
#                 'f1-score': 0.8216714413762306,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8807180081065431,
#                 'recall': 0.5713749060856499,
#                 'f1-score': 0.6930963773069037,
#                 'support': 7986.0},
#                '1': {'precision': 0.8177025083879214,
#                 'recall': 0.9613072877535688,
#                 'f1-score': 0.8837088837088837,
#                 'support': 15972.0},
#                'accuracy': 0.8313298271975957,
#                'macro avg': {'precision': 0.8492102582472323,
#                 'recall': 0.7663410969196094,
#                 'f1-score': 0.7884026305078937,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8387076749607952,
#                 'recall': 0.8313298271975957,
#                 'f1-score': 0.8201713815748902,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8804971319311663,
#                 'recall': 0.5766341096919609,
#                 'f1-score': 0.6968825665859564,
#                 'support': 7986.0},
#                '1': {'precision': 0.8194681759931653,
#                 'recall': 0.9608690207863761,
#                 'f1-score': 0.8845533141210374,
#                 'support': 15972.0},
#                'accuracy': 0.8327907170882377,
#                'macro avg': {'precision': 0.8499826539621658,
#                 'recall': 0.7687515652391685,
#                 'f1-score': 0.790717940353497,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8398111613058324,
#                 'recall': 0.8327907170882377,
#                 'f1-score': 0.8219963982760103,
#                 'support': 23958.0}},
#               {'0': {'precision': 0.8706684340087105,
#                 'recall': 0.5757575757575758,
#                 'f1-score': 0.6931484133564483,
#                 'support': 7986.0},
#                '1': {'precision': 0.818600417625957,
#                 'recall': 0.9572376659153519,
#                 'f1-score': 0.8825074316719097,
#                 'support': 15972.0},
#                'accuracy': 0.8300776358627598,
#                'macro avg': {'precision': 0.8446344258173337,
#                 'recall': 0.7664976208364638,
#                 'f1-score': 0.787827922514179,
#                 'support': 23958.0},
#                'weighted avg': {'precision': 0.8359564230868748,
#                 'recall': 0.8300776358627598,
#                 'f1-score': 0.8193877589000893,
#                 'support': 23958.0}}]})
